# %%
# Importing standard libraries
import os
import sys
import math
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from geopy.distance import geodesic
import logging
import geopandas as gpd
import osmnx as ox
from shapely.geometry import Point, Polygon, MultiPolygon
# Importing existing functions from 'circling' module
from circling import compute_heading_transition, _calc_bearing, compute_overall_heading, detect_overall_circling, detect_circling_behavior
import geopandas as gpd
# Importing custom IGC parser
from parser import igc2df  # Ensure this function correctly parses IGC files into DataFrames
import rasterio
from rasterio.features import rasterize
from rasterio.transform import from_origin, rowcol
from pathlib import Path
import tqdm 
from joblib import Parallel, delayed
import ee
from pyproj import Transformer
from pilot_behavior_functions import compute_time_weighted_average, extract_tas_field_positions, parse_b_records, get_true_airspeed_stats_for_engine_runs_from_row, get_all_engine_start_speeds, get_first_engine_agl, get_agl_all_events, count_pct_engine_starts_below_1000, LANDCOVER_CLASSES, calc_speed_mean_post_event_window, calc_speed_mean_std_pre_event_window, convert_to_datetime, define_time_window, load_flight_data, determine_steady_descent_during_pre_event_window, calculate_descent_rate, calculate_distance_traveled, detect_climb_attempt, detect_multiple_start_stop, clean_time_entries, get_first_engine_event, get_terrain_label_at_first_engine_event_gee, parse_int_list, parse_float_list, parse_engine_run_info, get_dem_elevation_gee
import re
from typing import Dict, List, Tuple, Any, Optional
from ee_helpers import ensure_ee_initialized, LANDCOVER_DATASET
# Out:
# Window Start: 2024-06-24 23:00:00 Window End: 2024-06-24 23:04:00

# %%
# Configure logging
logging.basicConfig(
    filename='flight_processing.log',
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s'
)

# %%
glider_types_df = pd.read_csv("glider-types - capstone.csv")

# %%
# Define the path to your CSV file
csv_file_path1 = 'transformed data 700 600 150/Flt-times-updated.586395.csv'
csv_file_path2 = 'transformed data 700 600 150/Flt-times-updated.586473_wgc.csv'
# Load the updated CSV
try:
    df1 = pd.read_csv(csv_file_path1)
    df2 = pd.read_csv(csv_file_path2)
    df =  pd.concat([df1, df2], ignore_index=True)
    logging.info("CSV file loaded and merged successfully.")
except Exception as e:
    logging.error(f"Error loading CSV file: {e}")
    sys.exit(1)
# Out:
# 2025-04-15 22:26:38,866 - INFO - CSV file loaded and merged successfully.

# %% [markdown]
# # List all files in the "TAS" folder.
# tas_files = set(os.listdir("TAS"))
#
# # Filter the DataFrame to keep only rows where the File is in the TAS folder.
# df= df[df["File"].isin(tas_files)]
#
#
# print(df.shape)

# %%
df['Gtype'] = df['Gtype'].astype(str).str.strip()

# %%
# Unique replacements dictionary (only new, non-repeating keys)
unique_replacements = {
    "15m_N369QT_JS-3": "JS3",
    "18mN369QTJS-3": "JS3",
    "JS3-18A860": "JS3",
    "808C": "DG-808 C",
    "808CComp": "DG-808 C",
    "808C Comp": "DG-808 C",
    "AMSFlightCaratA": "Carat",
    "Antares20E": "Antares 20E",
    "ApisM15m": "APIS",
    "Arcus": "ARCUS",
    "ArcusM": "ARCUS M",
    "Arcus M": "ARCUS M",
    "ARCUSM": "ARCUS M",
    "ARCUSM2pilot": "ARCUS M",
    "ArcusM2pilot": "ARCUS M",
    "ARCUST": "ARCUS T",
    "ArcusT": "ARCUS T",
    "as33": "AS 33ES",
    "AS 33 Es 18m": "AS 33ES",
    "AS 33Es 18m": "AS 33ES",
    "AS33-18": "AS 33ES",
    "AS33Es": "AS 33ES",
    "AS33ES": "AS 33ES",
    "18mAS33@ventus": "AS 33ES",
    "AS33Es18m": "AS 33ES",
    "ASW24E":"ASW-24E",
    "ASG 29E 15m": "ASW 27-18 E (ASG-29E)",
    "ASG 29E 18m": "ASW 27-18 E (ASG-29E)",
    "ASG 29ES": "ASW 27-18 E (ASG-29E)",
    "ASG 32 Mi": "ASG 32 MI",
    "ASG-29": "ASW 27-18 E (ASG-29E)",
    "ASG-32Mi": "ASG 32 MI",
    "ASG29": "ASW 27-18 E (ASG-29E)",
    "ASG2918": "ASW 27-18 E (ASG-29E)",
    "ASG29E": "ASW 27-18 E (ASG-29E)",
    "ASG29E.": "ASW 27-18 E (ASG-29E)",
    "ASG29E15m": "ASW 27-18 E (ASG-29E)",
    "ASG29E18m": "ASW 27-18 E (ASG-29E)",
    "ASG29Es": "ASW 27-18 E (ASG-29E)",
    "NixusAsh30polar": "ASH30 NIXUS",
    "ASG31Mi": "ASG31mi",
    "ASG32Mi": "ASG 32 MI",
    "ASG 32Mi": "ASG 32 MI",
    "ASG32mi": "ASG 32 MI",
    "ASH 31 MI-Wet": "ASH 31 MI",
    "ASH 31 MI18": "ASH 31 MI",
    "ASH 31 MI21m": "ASH 31 MI",
    "ASH 31/18m": "ASH 31 MI",
    "ASH 31 mi": "ASH 31 MI",
    "ASH 31/21m": "ASH 31 MI",
    "ASH-31": "ASH 31 MI",
    "ASH 31 Mi": "ASH 31 MI",
    "ASH31/18m": "ASH 31 MI",
    "ash-26e": "ASH 26 E",
    "ASH25mi": "ASH25M",
    "ASH26E": "ASH 26 E",
    "ASH 26E": "ASH 26 E",
    "ASH30Mi": "ASH 30 MI",
    "ASH31/21M": "ASH 31 MI",
    "ASH31/21m": "ASH 31 MI",
    "ASH31/21m-Wet": "ASH 31 MI",
    "ASH3118": "ASH 31 MI",
    "ASH3118Mjune": "ASH 31 MI",
    "ASH31  18M  june": "ASH 31 MI",
    "ASH31": "ASH 31 MI",
    "ASH3121": "ASH 31 MI",
    "ASH31mi": "ASH 31 MI",
    "ASH 31/21m-Wet": "ASH 31 MI",
    "ASH31MI": "ASH 31 MI",
    "ASH31Mi": "ASH 31 MI",
    "ASH31mi18": "ASH 31 MI",
    "ASH31Mi18m": "ASH 31 MI",
    "ASH31-18": "ASH 31 MI",
    "ASH31Mi21m": "ASH 31 MI",
    "ASH31mi21m": "ASH 31 MI",
    "AstirCS": "ASTIR CS",
    "ASW 27-18 E (ASG-29E)15m": "ASW 27-18 E (ASG-29E)",
    "ASG-29E-18": "ASW 27-18 E (ASG-29E)",
    "ASW 27-18 E (ASG-29E)18": "ASW 27-18 E (ASG-29E)",
    "ASW 27-18 E (ASG-29E)18M": "ASW 27-18 E (ASG-29E)",
    "ASW 27-18 E (ASG-29E)18m": "ASW 27-18 E (ASG-29E)",
    "ASW 27-18 E (ASG-29E)m": "ASW 27-18 E (ASG-29E)",
    "ASW 27-18 E (ASG-29E)s": "ASW 27-18 E (ASG-29E)",
    "ASG29ES": "ASW 27-18 E (ASG-29E)",
    "ASW-27b": "ASW 27",
    "ASW 27B": "ASW 27",
    "ASW-27FES": "ASW-27",
    "ASW-27Min5Pct": "ASW-27",
    "ASW15": "ASW-15",
    "ASW19": "ASW-19",
    "ASW20": "ASW20F",
    "ASW22BL": "ASW-22BL",
    "ASW24": "ASW-24",
    "ASW27": "ASW-27",
    "ASW27-18E": "ASW 27-18 E (ASG-29E)",
    "ASW2718": "ASW 27-18 E (ASG-29E)",
    'ASG29/18m': "ASW 27-18 E (ASG-29E)",
    'ASG2915m': "ASW 27-18 E (ASG-29E)",
    'ASG2918M': "ASW 27-18 E (ASG-29E)",
    'ASG29Es/18m': "ASW 27-18 E (ASG-29E)",
    "ASW27B": "ASW-27",
    "ASW27b": "ASW 27",
    "ASW27FES": "ASW 27",
    "ASW27Min5Pct": "ASW-27",
    "ASW28": "ASW-28",
    "CARAT": "Carat",
    "CaratA": "Carat",
    "Carat A": "Carat",
    "CARATA": "Carat",
    "DISCUS2A": "DISCUS 2A",
    "D2CT": "DISCUS-2CT",
    "Discus 2cT": "DISCUS-2CT",
    "Discus 2CT": "DISCUS-2CT",
    "DG-1000T": "DG-1000T",
    "DG-400/17m": "DG-400",
    "DG-400 17": "DG-400",
    "DG-40017": "DG-400",
    "DG-400M/17/17m": "DG-400M/17",
    "DG-800B/18m": "DG-800B",
    "DG-800B15": "DG-800B",
    "DG-800BB": "DG-800B",
    "DG-800BB15": "DG-800B",
    "DG-800BS/18m": "DG-800B",
    "DG800B": "DG-800B",
    'DG800B15': "DG-800B",
    "Dg-808": "DG-800B",
    "DG-808 C15": "DG-808 C",
    "DG-808 C18": "DG-808 C",
    "DG-808B": "DG-808 C",
    "DG-808C": "DG-808 C",
    "DG-808C18": "DG-808 C",
    "DG1000/20m": "DG-1000M",
    "DG1000t": "DG-1000T",
    "DG1001M": "DG-100",
    "DG400": "DG-400",
    "DG400/17m": "DG-400",
    "DG800": "DG-800",
    "dG800.15": "DG-800",
    "DG800/18m": "DG-800",
    "DG80015": "DG-800",
    "DG800S/18m": "DG-800S",
    "DG808B": "DG-808 C",
    "800B15": "DG-800B",
    "DG808B/18m": "DG-808 C",
    "DG800B": "DG-808 C",
    "DG800B15":"DG-808 C",
    "DG808C15":"DG-808 C",
    "DG808C18":"DG-808 C",
    "DG808c": "DG-808 C",
    "DG808C": "DG-808 C",
    "DG808S": "DG-808 S",
    "Diana-2": "SZD-56-3 DIANA-2 FES",
    "Diana2": "SZD-56-3 DIANA-2 FES",
    "Discu2": "DISCUS-2B",
    "Discus": "DISCUS",
    "DISCUS-2BA": "DISCUS-2B",
    "DISCUS-2Bb": "DISCUS-2B",
    "DISCUS-2BB": "DISCUS-2B",
    "DISCUS-2BC": "DISCUS-2B",
    "DISCUS-2BCT": "DISCUS-2B",
    "DISCUS-2Bct": "DISCUS-2B",
    "DISCUS-2BT/18m": "DISCUS-2B",
    "DISCUS-2C": "DISCUS-2CT",
    "Discus2": "DISCUS-2B",
    "DISCUS2": "DISCUS-2B",
    "Discus2b": "DISCUS-2B",
    "Discus2B": "DISCUS-2B",
    "Discus2c": "DISCUS 2C",
    "DISCUS2C": "DISCUS 2C",
    "Discus 2c": "DISCUS 2C",
    "DISCUS2CT": "DISCUS-2CT",
    "Discus2ct": "DISCUS-2CT",
    "Discus2CT": "DISCUS-2CT",
    "Discus2cT": "DISCUS-2CT",
    "Discus2T/18m": "DISCUS 2T",
    "DiscusbT": "DISCUS-2B",
    "DISCUSbT": "DISCUS BT",
    "DiscusCS": "DISCUS CS",
    "Discus CS": "DISCUS CS",
    "Discus 2": "DISCUS 2A",
    "DiscusIIa": "DISCUS 2A",
    "DUODISCU": "DUO DISCUS",
    "DuoDiscus": "DUO DISCUS",
    "DUODISCUS": "DUO DISCUS",
    "Duo Discus": "DUO DISCUS",
    "DUODiscus": "DUO DISCUS",
    "DuoDiscusT": "DUO DISCUS T",
    "DuoDiscusXL": "DUO DISCUS",
    "DuoDiscusXLT": "DUO DISCUS T",
    "EB29/25.3m": "EB29",
    "EB 29/28.3m": "EB29",
    "EB29/28.3m": "EB29",
    "EB 29/25.3m": "EB29",
    "EB 29R": "EB29R",
    "EB29RGBD": "EB29R",
    "Genesis2": "GENESIS 2",
    "GLASFLUGEL 304 MSS": "GLASFLUGEL 304 MS",
    "GLASFLUGEL 304S JETJ": "GLASFLUGEL 304S JET",
    "Glasflugel304MS": "GLASFLUGEL 304 MS",
    "HpH 304MS": "GLASFLUGEL 304 MS",
    "HpH 304M": "GLASFLUGEL 304 MS",
    "Hph304C": "GLASFLUGEL 304C",
    "HpH304M": "GLASFLUGEL 304 MS",
    "HpH304MS": "GLASFLUGEL 304 MS",
    "HpH304S": "GLASFLUGEL 304S JET",
    "Hph304S": "GLASFLUGEL 304S JET",
    "Hph304 S": "GLASFLUGEL 304S JET",
    "HpH304SJ": "GLASFLUGEL 304S JET",
    "HpH 304SJ": "GLASFLUGEL 304S JET",
    "JonkersJS3": "JS3",
    "18m N369QT JS-3": "JS3",
    "18m_N369QT_JS-3": "JS3",
    "JS-1": "JS1-C",
    "JS-1-18m": "JS1-C",
    "JS-1-21m": "JS1-C",
    "JS-3-15m": "JS3",
    "JS-3-18m": "JS3",
    "JS3-18m": "JS3",
    "JS1-C-21m": "JS1-C",
    "JS3jet": "JS3",
    "JS-3-18m jet": "JS3",
    "JS-3-18mjet": "JS3",
    "JS-3-18m_MM": "JS3",
    "JS-3-18mAbm": "JS3",
    "JS3-18A860": "JS3",
    "JS-5-24m": "JS-5",
    "JS5": "JS-5",
    "LAK-17A/18m": "LAK-17A",
    "LAK-17bMini": "LAK-17B FES MINI",
    "Lak-17bMini.": "LAK-17B FES MINI",
    "Lak-17b Mini.": "LAK-17B FES MINI",
    "LAK17/18m": "LAK-17B FES",
    "LAK17b FES": "LAK-17B FES",
    "LAK-13.5m FES": "LAK-17B FES",
    "LAK-13.5mFES": "LAK-17B FES",
    "LAK17AT": "LAK-17AT",
    "LAK17AT/18m": "LAK-17AT",
    "LAK17B-18FES": "LAK-17B FES",
    "LAK17BFES": "LAK-17B FES",
    "LAK17bFES": "LAK-17B FES",
    "LS-8": "LS8",
    "LS 10-s-18": "LS 10-ST",
    "LS10-s-18": "LS 10-ST",
    "LS10-st-18": "LS 10-ST",
    "LS 10-st-18": "LS 10-ST",
    "Ls10st": "LS 10-ST",
    "ls3a": "LS3-A",
    "LS4": "LS 4A",
    "LS_4": "LS 4A",
    "Nimbus3DM": "NIMBUS 3",
    "PIK20D": "PIK-20",
    "Pik_20e": "PIK-20E",
    "PW5": "PW-5",
    "PW5-Smyk": "PW-5",
    "PW5_Smyk": "PW-5",
    "S-10-VT": "S10-V",
    "SGS1-26": "SGS 1-26A",
    "SILENT 2 TARGAelec.": "SILENT 2 TARGA",
    "SILENT-IN_P": "SILENT-IN",
    "Silent2": "SILENT 2 TARGA",
    "Silent2elec.": "SILENT 2 ELECTRO",
    "Silent2 elec.": "SILENT 2 ELECTRO",
    "Silent_2": "SILENT 2 TARGA",
    "SILENT_IN": "SILENT-IN",
    "STANDARDCIRRUS": "STANDARD CIRRUS G/81",
    "Schweizer1.26":"SGS 1-26E",
    "SZD-55": "SZD-55-1",
    "TAURUS": "Taurus",
    "HpHTwinshark": "Twinshark",
    "304TSTwinSharkMTS": "Twinshark",
    "TEST": "TST-10 M",
    "TSt": "TST-10 M",
    "TST-10AtlasM": "TST-10 M",
    "TST10Atlas": "TST-10 M",
    "TST10M35L": "TST-10 M",
    "TST14M": "TST-10 M",
    "Unknown": "UNKNOWN",
    "V2CM": "VENTUS 2CM",
    "V2cxa": "VENTUS 2CX",
    "V2cxa16M": "VENTUS 2CX",
    "V2cxa15M": "VENTUS 2CX",
    "Ventus 2cxt-18": "VENTUS 2CXT",
    "V2cXT": "VENTUS 2CXT",
    "V2CXT": "VENTUS 2CXT",
    "V2cxt18": "VENTUS 2CXT",
    "V3F18": "VENTUS 3F",
    "Ventus 3F": "VENTUS 3F",
    "VENTUS 2CT": "VENTUS 2CT",
    "VENTUS 2CX15M": "VENTUS 2CX",
    "VENTUS 3F-15": "VENTUS 3F",
    "Ventus 3F 15m": "VENTUS 3F",
    "VENTUS 3F-15M": "VENTUS 3F",
    "VENTUS 3F-18": "VENTUS 3F",
    "VENTUS 3F15m": "VENTUS 3F",
    "VENTUS 3F18M": "VENTUS 3F",
    "Ventus 3FES": "VENTUS 3F",
    "Ventus-3FES": "VENTUS 3F",
    "Ventus 3": "VENTUS 3F",
    "Ventus 3 15m_V2": "VENTUS 3F",
    "Ventus 3F 18m": "VENTUS 3F",
    "Ventus2/15m": "VENTUS 2A",
    "Ventus2/18m": "VENTUS 2C",
    "Ventus2b": "VENTUS 2B",
    "Ventus2Bx": "VENTUS 2 BX",
    "Ventus2C": "VENTUS 2C",
    "Ventus2c": "VENTUS-2C",
    "Ventus2CM": "VENTUS 2CM",
    "VENTUS2cm": "VENTUS 2C",
    "Ventus2cM18m": "VENTUS 2CM",
    "VENTUS2CT": "VENTUS 2CT",
    "Ventus2Cx18": "VENTUS 2CX",
    "Ventus2CXFES": "VENTUS 2CX",
    "Ventus2cx": "VENTUS 2CX",
    "Ventus2cxM": "VENTUS 2CXM",
    "Ventus2CXM": "VENTUS 2CXM",
    "VENTUS2CX": "VENTUS 2CXM",
    "Ventus2Cxt": "VENTUS 2CXT",
    "Ventus2cxt": "VENTUS 2CXT",
    "Ventus2cxT": "VENTUS 2CXT",
    "VeNTUS2CxT": "VENTUS 2CXT",
    "Ventus2cxt-18": "VENTUS 2CXT",
    "Ventus 2cxt": "VENTUS 2CXT",
    "Ventus2cxt15": "VENTUS 2CXT",
    "Ventus2cxt18": "VENTUS 2CXT",
    "VENTUS2cxT18": "VENTUS 2CXT",
    "Ventus315m_V2": "VENTUS 3M",
    "Ventus3F": "VENTUS 3F",
    "Ventus3F18m": "VENTUS 3F",
    "Ventus3F15M": "VENTUS 3F",
    "Ventus3F15m": "VENTUS 3F",
    "Ventus3F-15": "VENTUS 3F",
    'Ventus3F-18': "VENTUS 3F",
    'Ventus3F18M': "VENTUS 3F",
    "Ventus3FES": "VENTUS 3F",
    "Ventus3M": "VENTUS 3M",
    "Ventus3M032021": "VENTUS 3M",
    "Ventus3M18m": "VENTUS 3M",
    "Ventus3M18M": "VENTUS 3M",
    "Ventus3M2021": "VENTUS 3M",
    "Ventus3M2021DLR": "VENTUS 3M",
    "Ventus3MDLR": "VENTUS 3M",
    "Ventus 3M 032021": "VENTUS 3M",
    "Ventus 3M 2021": "VENTUS 3M",
    "Ventus 3M 2021 DLR": "VENTUS 3M",
    "Ventus3t": "VENTUS 3T",
    "Ventus3T18_W": "VENTUS 3T",
    "Ventus 3T 18_W": "VENTUS 3T",
    "Ventus3T": "VENTUS 3T",
    "VENTUSB": "VENTUS B/16.6",
    "VentusbT16.6m": "VENTUS BT",
    "VentusC/17m": "VENTUS C",
    "VENTUSCT": "VENTUS CT",
    "VETNUSCM": "VENTUS CM",
    "VENTUSCM": "VENTUS CM"
}

# Apply the unique replacements to the 'Gtype' column:
df['Gtype'] = df['Gtype'].replace(unique_replacements, regex=False)

# %%
len(df['Gtype'].unique())
# Out:
# 117

# %%
df['Gtype'].unique()
# Out:
# array(['VENTUS 3F', 'LAK-17B FES', 'VENTUS 3M', 'UNKNOWN', 'DG-800',
#        'ASH 31 MI', 'TST-10 M', 'DISCUS-2B', 'VENTUS 2CXM', 'ASW-27',
#        'ASW 27-18 E (ASG-29E)', 'VENTUS15', 'ARCUS', 'ASH 26 E', 'U',
#        'SZD-55-1', 'ASG 32 MI', 'VENTUS 2CXT', 'JS1-C', 'PIK-20',
#        'ARCUS M', 'SILENT-IN', 'SZD-56-3 DIANA-2 FES', 'AS 33ES',
#        'DISCUS-2CT', 'JS3', 'DG-400', 'VENTUS 2CT', 'ASH 30 MI', '18M',
#        'DG-808 C', 'DISCUS CS', 'DG-800B', 'Ventus2', 'DISCUS 2C',
#        'Antares 20E', 'ARCUS T', 'LAK-17AT', 'GLASFLUGEL 304 MS',
#        'VENTUS 2B', 'ASW-27B', 'Carat', 'VENTUS 2CM', 'Taurus',
#        'GENESIS 2', 'Nimeta', 'ASW 27', 'GLASFLUGEL 304C', 'EB29',
#        'LS8-18', 'DISCUS', 'VENTUS 2A', '21M', 'LS-4', 'VENTUS 2C',
#        'DISCUS 2T', 'SILENT 2 TARGA', 'DUO DISCUS T', 'ASH25M',
#        'VENTUS CT', 'ASW20F', 'VENTUS-2C', 'STANDARD CIRRUS G/81',
#        'Uentus2b', 'VENTUS 2CX', 'VENTUS2/15', 'ASW-24E', 'DG-808 S',
#        'AC-5M', 'DUO DISCUS', 'LS 4A', 'VENTUS B/16.6', 'ASW-22BL',
#        'Motorglider', 'DISCUS 2A', 'SILENT 2 ELECTRO', 'PIK20E', 'LAK-12',
#        'DG-1000M', 'Default', 'ASW-24', 'DG-1000T', 'LS 10-ST',
#        'VENTUS CM', 'LS8', '21', 'Ventus3', 'ASW-15', 'ASW-28',
#        'VENTUS 2 BX', 'PW-5', 'LS-10', 'nan', 'LS3-A', 'ventus2a',
#        'ANTARES18S', 'VentusN139P', 'DG-100', 'DG-800S', 'VENTUS BT',
#        'EB29R', 'VENTUS 3T', 'LAK-17B FES MINI', 'GLASFLUGEL 304S JET',
#        'Twinshark', 'NIMBUS 3', 'N808EE', 'SGS 1-26A', 'S10-V', 'ASW-19',
#        'PIK-20E', 'APIS', 'SGS 1-26E', 'ASTIR CS', 'VENTUS C',
#        'ASH30 NIXUS', 'JS-5'], dtype=object)

# %%
#df = df.head(500)

# %%
pure_gliders = pd.read_csv('glider-types - Pure Gliders.csv')

pure_gliders = pure_gliders['Manufacture']

df = df[~df['Gtype'].isin(pure_gliders)]
df = df[df['Gtype']!='Unknown']
# Optionally, reset the index

# %%
len(df['Gtype'].unique())
# Out:
# 59

# %%
exclude = ['18M', '21', '21M', 'ANTARES18S', 'Default', 'Motorglider', 'nan', 'U', 'Uentus2b', 
           'VENTUS15', 'Ventus2', 'VENTUS2/15', 'ventus2a', 'Ventus3', 'VentusN139P']
df = df[~df['Gtype'].isin(exclude)]

# %%
sorted_unique_gtypes = sorted(df['Gtype'].unique(), key=str.lower)
sorted_unique_gtypes
# Out:
# ['AC-5M',
#  'Antares 20E',
#  'ARCUS M',
#  'AS 33ES',
#  'ASG 32 MI',
#  'ASH 26 E',
#  'ASH 30 MI',
#  'ASH 31 MI',
#  'ASH25M',
#  'ASH30 NIXUS',
#  'ASW 27-18 E (ASG-29E)',
#  'ASW-24E',
#  'Carat',
#  'DG-1000M',
#  'DG-1000T',
#  'DG-400',
#  'DG-800B',
#  'DG-808 C',
#  'DISCUS-2CT',
#  'DUO DISCUS T',
#  'EB29',
#  'EB29R',
#  'JS-5',
#  'LAK-17AT',
#  'LAK-17B FES MINI',
#  'LS 10-ST',
#  'LS-10',
#  'N808EE',
#  'Nimeta',
#  'PIK20E',
#  'SILENT 2 ELECTRO',
#  'SILENT-IN',
#  'SZD-56-3 DIANA-2 FES',
#  'Taurus',
#  'Twinshark',
#  'VENTUS 2CM',
#  'VENTUS 2CT',
#  'VENTUS 2CX',
#  'VENTUS 2CXM',
#  'VENTUS 3F',
#  'VENTUS 3M',
#  'VENTUS 3T',
#  'VENTUS CM',
#  'VENTUS CT']

# %%
# Create a folder called "dropped" in the current directory if it doesn't exist
dropped_folder = "dropped"
os.makedirs(dropped_folder, exist_ok=True)

# --- Step 1: Drop rows where 'Sensor Info' is NaN ---
# Identify the rows to drop (for later saving)
dropped_sensor_info = df[df['Sensor Info'].isna()].copy()
# Drop them from df
df = df.dropna(subset=['Sensor Info'])

# --- Step 2: Drop rows where ALL three engine run start time columns are NaN ---
engine_cols = ["ENL_Engine_Run_Start_Times", "MOP_Engine_Run_Start_Times", "RPM_Engine_Run_Start_Times"]

# One-line drop: this drops rows if all specified columns are NaN.
# But first, save the rows that will be dropped.
mask_all_null = df[engine_cols].isna().all(axis=1)
dropped_engine_runs = df[mask_all_null].copy()
df = df.dropna(subset=engine_cols, how='all')

# --- Step 3: Save the dropped rows into CSV files inside the "dropped" folder ---
dropped_sensor_info.to_csv(os.path.join(dropped_folder, "dropped_sensor_info.csv"), index=False)
dropped_engine_runs.to_csv(os.path.join(dropped_folder, "dropped_engine_runs.csv"), index=False)

# %%
sensor_cols = ["ENL_Engine_Run_Start_Times", "MOP_Engine_Run_Start_Times", "RPM_Engine_Run_Start_Times"]

for col in sensor_cols:
    if col in df.columns:
        df[col] = df[col].apply(
            lambda x: (
                ",".join(
                    ("" if float(item) == 0 else str(int(float(item)))
                      for item in str(x).split(",") if item.strip())
                )
            ) if pd.notnull(x) else x
        )

# %%
# Assume glider_types_df is already defined (e.g., loaded from your CSV)
# and get_first_engine_event is defined as per our previous discussion.

# Apply get_first_engine_event to each row, storing the result in a temporary DataFrame.
event_df = df.apply(
    lambda row: get_first_engine_event(
        row,
        sensor_types=["ENL", "MOP", "RPM"],
        glider_types_df=glider_types_df
    ),
    axis=1
)

# Join the new event columns back into your original DataFrame.
df = df.join(event_df)
# Out:
# 2025-04-15 22:26:47,225 - WARNING - Row 46PGA9D1.IGC: Self-Launch glider 'VENTUS 3M' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,226 - WARNING - Row 2023-08-15-CNI-25N-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,227 - WARNING - Row 2016-08-07-CNI-255-01.IGC: Self-Launch glider 'VENTUS 2CXM' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,228 - INFO - Row 2020-08-18-CNI-20Y-01.IGC: Not a Self-Launch glider, using earliest engine event time 165705.
# 2025-04-15 22:26:47,228 - INFO - Row 2020-08-18-CNI-20Y-01.IGC: first_event_time set to 165705 from sensor(s): ENL
# 2025-04-15 22:26:47,229 - INFO - Row 46RGJUM1.IGC: Not a Self-Launch glider, using earliest engine event time 193703.
# 2025-04-15 22:26:47,229 - INFO - Row 46RGJUM1.IGC: first_event_time set to 193703 from sensor(s): ENL
# 2025-04-15 22:26:47,230 - WARNING - Row 2021-06-02-CNI-27D-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,231 - WARNING - Row 25HC48C1.IGC: Self-Launch glider 'ASH 26 E' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,231 - WARNING - Row 2023-08-20-CNI-25N-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,232 - INFO - Row 2018-06-29-NKL-10Q-01.IGC: Not a Self-Launch glider, using earliest engine event time 184738.
# 2025-04-15 22:26:47,232 - INFO - Row 2018-06-29-NKL-10Q-01.IGC: first_event_time set to 184738 from sensor(s): ENL
# 2025-04-15 22:26:47,233 - INFO - Row 2018-06-09-CNI-20E-01.IGC: Not a Self-Launch glider, using earliest engine event time 202616.
# 2025-04-15 22:26:47,233 - INFO - Row 2018-06-09-CNI-20E-01.IGC: first_event_time set to 202616 from sensor(s): ENL
# 2025-04-15 22:26:47,234 - WARNING - Row 2017-04-17-LXV-2RN-01.IGC: Self-Launch glider 'ASH 26 E' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,235 - INFO - Row 2023-06-04-LXV-NBR-01.IGC: Not a Self-Launch glider, using earliest engine event time 171802.
# 2025-04-15 22:26:47,236 - INFO - Row 2023-06-04-LXV-NBR-01.IGC: first_event_time set to 171802 from sensor(s): MOP
# 2025-04-15 22:26:47,236 - WARNING - Row 2021-06-16-CNI-236-01.IGC: Self-Launch glider 'ASG 32 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,237 - INFO - Row 2018-08-18-CNI-232-01.IGC: Self-Launch glider 'ASH 31 MI', using second unique engine event time 223424 from sensor(s): ENL
# 2025-04-15 22:26:47,237 - INFO - Row 2018-08-18-CNI-232-01.IGC: first_event_time set to 223424 from sensor(s): ENL
# 2025-04-15 22:26:47,238 - WARNING - Row 2018-08-19-CNI-27D-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,239 - WARNING - Row 2016-08-10-CNI-22M-01.IGC: Self-Launch glider 'ARCUS M' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,240 - WARNING - Row 34PLCS74.IGC: Self-Launch glider 'SILENT-IN' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,241 - WARNING - Row 2023-06-26-LXV-7EO-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,241 - INFO - Row 03EGIQO1.IGC: Not a Self-Launch glider, using earliest engine event time 210805.
# 2025-04-15 22:26:47,242 - INFO - Row 03EGIQO1.IGC: first_event_time set to 210805 from sensor(s): ENL
# 2025-04-15 22:26:47,242 - INFO - Row 2024-08-04-CNI-29F-01.IGC: Not a Self-Launch glider, using earliest engine event time 165847.
# 2025-04-15 22:26:47,243 - INFO - Row 2024-08-04-CNI-29F-01.IGC: first_event_time set to 165847 from sensor(s): ENL
# 2025-04-15 22:26:47,243 - INFO - Row 2014-05-22-NKL-10R-01.IGC: Not a Self-Launch glider, using earliest engine event time 192935.
# 2025-04-15 22:26:47,244 - INFO - Row 2014-05-22-NKL-10R-01.IGC: first_event_time set to 192935 from sensor(s): ENL
# 2025-04-15 22:26:47,244 - WARNING - Row 23IGA9D1.IGC: Self-Launch glider 'VENTUS 3M' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,245 - INFO - Row 2013-04-25-NKL-10Q-01.IGC: Not a Self-Launch glider, using earliest engine event time 191818.
# 2025-04-15 22:26:47,245 - INFO - Row 2013-04-25-NKL-10Q-01.IGC: first_event_time set to 191818 from sensor(s): ENL
# 2025-04-15 22:26:47,246 - WARNING - Row 2021-06-19-LXV-780-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,248 - WARNING - Row 2018-06-20-CNI-27D-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,248 - INFO - Row 2016-05-26-CNI-21L-01.IGC: Not a Self-Launch glider, using earliest engine event time 193128.
# 2025-04-15 22:26:47,249 - INFO - Row 2016-05-26-CNI-21L-01.IGC: first_event_time set to 193128 from sensor(s): ENL
# 2025-04-15 22:26:47,249 - INFO - Row 2018-03-14-CNI-20E-01.IGC: Not a Self-Launch glider, using earliest engine event time 193436.
# 2025-04-15 22:26:47,250 - INFO - Row 2018-03-14-CNI-20E-01.IGC: first_event_time set to 193436 from sensor(s): ENL
# 2025-04-15 22:26:47,250 - INFO - Row 2017-03-15-CNI-22G-01.IGC: Self-Launch glider 'ASH 30 MI', using second unique engine event time 185048 from sensor(s): ENL
# 2025-04-15 22:26:47,251 - INFO - Row 2017-03-15-CNI-22G-01.IGC: first_event_time set to 185048 from sensor(s): ENL
# 2025-04-15 22:26:47,251 - WARNING - Row 2021-06-02-FLA-JEU-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,252 - WARNING - Row 2019-06-05-CNI-27K-01.IGC: Self-Launch glider 'DG-808 C' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,253 - WARNING - Row 2017-06-09-CNI-22G-01.IGC: Self-Launch glider 'ASH 30 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,254 - INFO - Row 06CC4A41.IGC: Self-Launch glider 'Antares 20E', using second unique engine event time 173229 from sensor(s): ENL
# 2025-04-15 22:26:47,254 - INFO - Row 06CC4A41.IGC: first_event_time set to 173229 from sensor(s): ENL
# 2025-04-15 22:26:47,255 - WARNING - Row 2016-05-24-NKL-0UM-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,255 - WARNING - Row 2021-08-04-CNI-23Y-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,256 - WARNING - Row 2021-06-20-LXV-780-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,257 - WARNING - Row 2018-08-09-CNI-232-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,258 - INFO - Row 2017-06-27-CNI-23P-01.IGC: Not a Self-Launch glider, using earliest engine event time 224417.
# 2025-04-15 22:26:47,258 - INFO - Row 2017-06-27-CNI-23P-01.IGC: first_event_time set to 224417 from sensor(s): ENL
# 2025-04-15 22:26:47,259 - WARNING - Row 2019-06-20-CNI-27D-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,259 - WARNING - Row 2019-06-23-CNI-27D-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,260 - INFO - Row 2015-10-12-CNI-20Y-01.IGC: Not a Self-Launch glider, using earliest engine event time 184955.
# 2025-04-15 22:26:47,260 - INFO - Row 2015-10-12-CNI-20Y-01.IGC: first_event_time set to 184955 from sensor(s): ENL
# 2025-04-15 22:26:47,261 - WARNING - Row 46MG8KM1.IGC: Self-Launch glider 'DG-400' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,262 - INFO - Row 2021-04-18-CNI-21D-01.IGC: Self-Launch glider 'DG-808 C', using second unique engine event time 174403 from sensor(s): ENL
# 2025-04-15 22:26:47,262 - INFO - Row 2021-04-18-CNI-21D-01.IGC: first_event_time set to 174403 from sensor(s): ENL
# 2025-04-15 22:26:47,263 - WARNING - Row 2021-07-20-LXV-780-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,263 - WARNING - Row 561LCS71.IGC: Self-Launch glider 'SILENT-IN' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,264 - INFO - Row 2024-06-17-CNI-27Z-01.IGC: Not a Self-Launch glider, using earliest engine event time 225843.
# 2025-04-15 22:26:47,264 - INFO - Row 2024-06-17-CNI-27Z-01.IGC: first_event_time set to 225843 from sensor(s): ENL
# 2025-04-15 22:26:47,265 - INFO - Row 2020-03-13-CNI-27G-01.IGC: Not a Self-Launch glider, using earliest engine event time 210041.
# 2025-04-15 22:26:47,265 - INFO - Row 2020-03-13-CNI-27G-01.IGC: first_event_time set to 210041 from sensor(s): ENL
# 2025-04-15 22:26:47,266 - WARNING - Row 2021-06-04-CNI-27D-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,267 - WARNING - Row 14HG8KM1.IGC: Self-Launch glider 'DG-400' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,268 - INFO - Row 2017-08-10-CNI-20Y-01.IGC: Not a Self-Launch glider, using earliest engine event time 220256.
# 2025-04-15 22:26:47,268 - INFO - Row 2017-08-10-CNI-20Y-01.IGC: first_event_time set to 220256 from sensor(s): ENL
# 2025-04-15 22:26:47,269 - INFO - Row 2019-04-24-CNI-22A-01.IGC: Not a Self-Launch glider, using earliest engine event time 213739.
# 2025-04-15 22:26:47,269 - INFO - Row 2019-04-24-CNI-22A-01.IGC: first_event_time set to 213739 from sensor(s): ENL
# 2025-04-15 22:26:47,270 - WARNING - Row 2019-08-21-CNI-23Y-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,270 - WARNING - Row 2021-03-15-LXV-AGO-02.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,271 - INFO - Row 2021-06-28-CNI-27Z-01.IGC: Not a Self-Launch glider, using earliest engine event time 233131.
# 2025-04-15 22:26:47,271 - INFO - Row 2021-06-28-CNI-27Z-01.IGC: first_event_time set to 233131 from sensor(s): ENL
# 2025-04-15 22:26:47,272 - INFO - Row 03FGIQO1.IGC: Not a Self-Launch glider, using earliest engine event time 172239.
# 2025-04-15 22:26:47,272 - INFO - Row 03FGIQO1.IGC: first_event_time set to 172239 from sensor(s): ENL
# 2025-04-15 22:26:47,273 - WARNING - Row 2018-07-01-LXV-3IL-01.IGC: Self-Launch glider 'DG-808 C' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,274 - INFO - Row 2019-07-16-CNI-20Y-01.IGC: Not a Self-Launch glider, using earliest engine event time 183730.
# 2025-04-15 22:26:47,274 - INFO - Row 2019-07-16-CNI-20Y-01.IGC: first_event_time set to 183730 from sensor(s): ENL
# 2025-04-15 22:26:47,275 - INFO - Row 2017-09-23-CNI-20Y-01.IGC: Not a Self-Launch glider, using earliest engine event time 191128.
# 2025-04-15 22:26:47,275 - INFO - Row 2017-09-23-CNI-20Y-01.IGC: first_event_time set to 191128 from sensor(s): ENL
# 2025-04-15 22:26:47,276 - WARNING - Row 46NG8KM1.IGC: Self-Launch glider 'DG-400' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,277 - WARNING - Row 2021-06-29-CNI-27D-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,277 - INFO - Row 2024-04-26-LXV-NBR-01.IGC: Not a Self-Launch glider, using earliest engine event time 182328.
# 2025-04-15 22:26:47,278 - INFO - Row 2024-04-26-LXV-NBR-01.IGC: first_event_time set to 182328 from sensor(s): MOP
# 2025-04-15 22:26:47,278 - WARNING - Row 2018-07-05-LXV-3IL-01.IGC: Self-Launch glider 'DG-808 C' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,279 - INFO - Row 2022-07-17-CNI-20Y-01.IGC: Not a Self-Launch glider, using earliest engine event time 182756.
# 2025-04-15 22:26:47,279 - INFO - Row 2022-07-17-CNI-20Y-01.IGC: first_event_time set to 182756 from sensor(s): ENL
# 2025-04-15 22:26:47,280 - INFO - Row 2019-05-07-CNI-27G-01.IGC: Not a Self-Launch glider, using earliest engine event time 210037.
# 2025-04-15 22:26:47,280 - INFO - Row 2019-05-07-CNI-27G-01.IGC: first_event_time set to 210037 from sensor(s): ENL
# 2025-04-15 22:26:47,281 - WARNING - Row 2017-04-17-LXV-JD2-01.IGC: Self-Launch glider 'VENTUS 2CM' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,282 - INFO - Row 2021-06-05-FLA-JUM-01.IGC: Not a Self-Launch glider, using earliest engine event time 200053.
# 2025-04-15 22:26:47,282 - INFO - Row 2021-06-05-FLA-JUM-01.IGC: first_event_time set to 200053 from sensor(s): ENL
# 2025-04-15 22:26:47,283 - WARNING - Row 2015-03-17-NKL-0VP-01.IGC: Self-Launch glider 'Taurus' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,283 - INFO - Row 2013-06-24-NKL-0T9-01.IGC: Not a Self-Launch glider, using earliest engine event time 193708.
# 2025-04-15 22:26:47,284 - INFO - Row 2013-06-24-NKL-0T9-01.IGC: first_event_time set to 193708 from sensor(s): ENL
# 2025-04-15 22:26:47,284 - INFO - Row 2016-04-18-CNI-21L-01.IGC: Not a Self-Launch glider, using earliest engine event time 192140.
# 2025-04-15 22:26:47,285 - INFO - Row 2016-04-18-CNI-21L-01.IGC: first_event_time set to 192140 from sensor(s): ENL
# 2025-04-15 22:26:47,285 - WARNING - Row 2024-06-07-CNI-24W-01.IGC: No glider type information found for Gtype 'Nimeta'.
# 2025-04-15 22:26:47,286 - INFO - Row 2024-06-07-CNI-24W-01.IGC: Not a Self-Launch glider, using earliest engine event time 193934.
# 2025-04-15 22:26:47,286 - INFO - Row 2024-06-07-CNI-24W-01.IGC: first_event_time set to 193934 from sensor(s): ENL
# 2025-04-15 22:26:47,286 - INFO - Row 2019-07-19-CNI-20Y-01.IGC: Not a Self-Launch glider, using earliest engine event time 185613.
# 2025-04-15 22:26:47,287 - INFO - Row 2019-07-19-CNI-20Y-01.IGC: first_event_time set to 185613 from sensor(s): ENL
# 2025-04-15 22:26:47,287 - WARNING - Row 2021-06-14-FLA-8DI-01.IGC: Self-Launch glider 'DG-808 C' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,288 - INFO - Row 2011-08-06-NKL-0Z0-01.IGC: Not a Self-Launch glider, using earliest engine event time 183739.
# 2025-04-15 22:26:47,288 - INFO - Row 2011-08-06-NKL-0Z0-01.IGC: first_event_time set to 183739 from sensor(s): ENL
# 2025-04-15 22:26:47,289 - INFO - Row 2017-08-03-CNI-20E-01.IGC: Not a Self-Launch glider, using earliest engine event time 214235.
# 2025-04-15 22:26:47,289 - INFO - Row 2017-08-03-CNI-20E-01.IGC: first_event_time set to 214235 from sensor(s): ENL
# 2025-04-15 22:26:47,290 - WARNING - Row 36FLCLO1.IGC: Self-Launch glider 'DG-808 C' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,291 - INFO - Row 2016-03-16-CNI-22G-01.IGC: Self-Launch glider 'ASH 30 MI', using second unique engine event time 203752 from sensor(s): ENL
# 2025-04-15 22:26:47,291 - INFO - Row 2016-03-16-CNI-22G-01.IGC: first_event_time set to 203752 from sensor(s): ENL
# 2025-04-15 22:26:47,292 - INFO - Row 2019-04-24-CNI-27G-01.IGC: Not a Self-Launch glider, using earliest engine event time 194355.
# 2025-04-15 22:26:47,292 - INFO - Row 2019-04-24-CNI-27G-01.IGC: first_event_time set to 194355 from sensor(s): ENL
# 2025-04-15 22:26:47,293 - INFO - Row 04NC4A41.IGC: Self-Launch glider 'Antares 20E', using second unique engine event time 204132 from sensor(s): ENL
# 2025-04-15 22:26:47,293 - INFO - Row 04NC4A41.IGC: first_event_time set to 204132 from sensor(s): ENL
# 2025-04-15 22:26:47,294 - WARNING - Row 2021-05-31-CNI-27D-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,294 - INFO - Row 2018-03-11-CNI-20E-01.IGC: Not a Self-Launch glider, using earliest engine event time 194026.
# 2025-04-15 22:26:47,295 - INFO - Row 2018-03-11-CNI-20E-01.IGC: first_event_time set to 194026 from sensor(s): ENL
# 2025-04-15 22:26:47,295 - WARNING - Row 339LCLO1.IGC: Self-Launch glider 'DG-808 C' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,296 - WARNING - Row 2018-07-04-LXV-3IL-01.IGC: Self-Launch glider 'DG-808 C' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,297 - WARNING - Row 2019-09-15-CNI-23Y-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,298 - WARNING - Row 2023-08-24-CNI-25N-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,298 - INFO - Row 04LC4A41.IGC: Self-Launch glider 'Antares 20E', using second unique engine event time 212044 from sensor(s): ENL
# 2025-04-15 22:26:47,299 - INFO - Row 04LC4A41.IGC: first_event_time set to 212044 from sensor(s): ENL
# 2025-04-15 22:26:47,299 - WARNING - Row 2024-06-22-CNI-27D-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,300 - INFO - Row 2019-06-17-CNI-20E-01.IGC: Not a Self-Launch glider, using earliest engine event time 202311.
# 2025-04-15 22:26:47,300 - INFO - Row 2019-06-17-CNI-20E-01.IGC: first_event_time set to 202311 from sensor(s): ENL
# 2025-04-15 22:26:47,301 - WARNING - Row 14IGA531.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,302 - INFO - Row 2022-03-13-CNI-27G-01.IGC: Not a Self-Launch glider, using earliest engine event time 211556.
# 2025-04-15 22:26:47,306 - INFO - Row 2022-03-13-CNI-27G-01.IGC: first_event_time set to 211556 from sensor(s): ENL
# 2025-04-15 22:26:47,307 - WARNING - Row 44OLCS71.IGC: Self-Launch glider 'SILENT-IN' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,307 - INFO - Row 2017-03-17-CNI-22G-01.IGC: Self-Launch glider 'ASH 30 MI', using second unique engine event time 172011 from sensor(s): ENL
# 2025-04-15 22:26:47,308 - INFO - Row 2017-03-17-CNI-22G-01.IGC: first_event_time set to 172011 from sensor(s): ENL
# 2025-04-15 22:26:47,308 - INFO - Row 2018-04-19-NKL-10Q-01.IGC: Not a Self-Launch glider, using earliest engine event time 182808.
# 2025-04-15 22:26:47,309 - INFO - Row 2018-04-19-NKL-10Q-01.IGC: first_event_time set to 182808 from sensor(s): ENL
# 2025-04-15 22:26:47,309 - WARNING - Row 2023-08-17-CNI-25N-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,310 - WARNING - Row 2021-07-22-LXV-780-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,311 - WARNING - Row 03DG8KM1.IGC: Self-Launch glider 'DG-400' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,312 - INFO - Row 2015-06-06-CNI-V8R-01.IGC: Self-Launch glider 'DG-400', using second unique engine event time 202236 from sensor(s): ENL
# 2025-04-15 22:26:47,312 - INFO - Row 2015-06-06-CNI-V8R-01.IGC: first_event_time set to 202236 from sensor(s): ENL
# 2025-04-15 22:26:47,313 - INFO - Row 2016-04-19-CNI-20E-01.IGC: Not a Self-Launch glider, using earliest engine event time 203151.
# 2025-04-15 22:26:47,313 - INFO - Row 2016-04-19-CNI-20E-01.IGC: first_event_time set to 203151 from sensor(s): ENL
# 2025-04-15 22:26:47,314 - WARNING - Row 2019-07-19-CNI-27D-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,314 - WARNING - Row 2019-08-20-CNI-23Y-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,315 - WARNING - Row 2024-06-01-CNI-242-01.IGC: Self-Launch glider 'ARCUS M' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,316 - INFO - Row 05JE6AB1.IGC: Not a Self-Launch glider, using earliest engine event time 204022.
# 2025-04-15 22:26:47,316 - INFO - Row 05JE6AB1.IGC: first_event_time set to 204022 from sensor(s): ENL
# 2025-04-15 22:26:47,317 - WARNING - Row 2023-06-29-LXV-7EO-02.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,318 - INFO - Row 2021-06-15-LXV-780-01.IGC: Self-Launch glider 'ASH 31 MI', using second unique engine event time 221621 from sensor(s): ENL
# 2025-04-15 22:26:47,318 - INFO - Row 2021-06-15-LXV-780-01.IGC: first_event_time set to 221621 from sensor(s): ENL
# 2025-04-15 22:26:47,319 - INFO - Row 2012-10-13-NKL-10R-01.IGC: Not a Self-Launch glider, using earliest engine event time 163135.
# 2025-04-15 22:26:47,319 - INFO - Row 2012-10-13-NKL-10R-01.IGC: first_event_time set to 163135 from sensor(s): ENL
# 2025-04-15 22:26:47,320 - WARNING - Row 35JC48C3.IGC: Self-Launch glider 'ASH 26 E' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,320 - INFO - Row 2018-03-13-NKL-0TK-01.IGC: Self-Launch glider 'ASH25M', using second unique engine event time 165040 from sensor(s): ENL
# 2025-04-15 22:26:47,321 - INFO - Row 2018-03-13-NKL-0TK-01.IGC: first_event_time set to 165040 from sensor(s): ENL
# 2025-04-15 22:26:47,321 - WARNING - Row 46AGA9D1.IGC: Self-Launch glider 'VENTUS 3M' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,322 - INFO - Row 2024-06-24-CNI-27D-01.IGC: Self-Launch glider 'ASH 31 MI', using second unique engine event time 210524 from sensor(s): ENL
# 2025-04-15 22:26:47,322 - INFO - Row 2024-06-24-CNI-27D-01.IGC: first_event_time set to 210524 from sensor(s): ENL
# 2025-04-15 22:26:47,323 - INFO - Row 05JC3KG1.IGC: Not a Self-Launch glider, using earliest engine event time 185330.
# 2025-04-15 22:26:47,323 - INFO - Row 05JC3KG1.IGC: first_event_time set to 185330 from sensor(s): ENL
# 2025-04-15 22:26:47,324 - WARNING - Row 2019-06-18-CNI-27D-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,325 - INFO - Row 2014-08-04-NKL-10X-01.IGC: Self-Launch glider 'ARCUS M', using second unique engine event time 222221 from sensor(s): ENL
# 2025-04-15 22:26:47,325 - INFO - Row 2014-08-04-NKL-10X-01.IGC: first_event_time set to 222221 from sensor(s): ENL
# 2025-04-15 22:26:47,326 - INFO - Row 2018-06-14-CNI-20E-01.IGC: Not a Self-Launch glider, using earliest engine event time 223847.
# 2025-04-15 22:26:47,326 - INFO - Row 2018-06-14-CNI-20E-01.IGC: first_event_time set to 223847 from sensor(s): ENL
# 2025-04-15 22:26:47,327 - INFO - Row 2018-06-17-CNI-20B-01.IGC: Self-Launch glider 'ARCUS M', using second unique engine event time 193959 from sensor(s): ENL
# 2025-04-15 22:26:47,327 - INFO - Row 2018-06-17-CNI-20B-01.IGC: first_event_time set to 193959 from sensor(s): ENL
# 2025-04-15 22:26:47,328 - WARNING - Row 2018-08-17-CNI-232-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,328 - WARNING - Row 15ALCS71.IGC: Self-Launch glider 'SILENT-IN' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,329 - INFO - Row 2017-07-31-NKL-0T9-01.IGC: Not a Self-Launch glider, using earliest engine event time 180520.
# 2025-04-15 22:26:47,329 - INFO - Row 2017-07-31-NKL-0T9-01.IGC: first_event_time set to 180520 from sensor(s): ENL
# 2025-04-15 22:26:47,330 - WARNING - Row 171GKXT1.IGC: Self-Launch glider 'VENTUS 3M' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,331 - WARNING - Row 24GLCLO1.IGC: Self-Launch glider 'DG-808 C' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,332 - WARNING - Row 2017-07-30-CNI-255-01.IGC: Self-Launch glider 'VENTUS 2CXM' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,332 - INFO - Row 2015-06-05-CNI-21D-01.IGC: Self-Launch glider 'DG-808 C', using second unique engine event time 180348 from sensor(s): ENL
# 2025-04-15 22:26:47,333 - INFO - Row 2015-06-05-CNI-21D-01.IGC: first_event_time set to 180348 from sensor(s): ENL
# 2025-04-15 22:26:47,333 - WARNING - Row 44LV1OL1.IGC: Self-Launch glider 'DG-808 C' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,334 - WARNING - Row 2019-08-24-CNI-23Y-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,335 - INFO - Row 2015-05-16-CNI-214-01.IGC: Self-Launch glider 'Taurus', using second unique engine event time 172057 from sensor(s): ENL
# 2025-04-15 22:26:47,335 - INFO - Row 2015-05-16-CNI-214-01.IGC: first_event_time set to 172057 from sensor(s): ENL
# 2025-04-15 22:26:47,336 - INFO - Row 2019-10-11-LXV-2RN-01.IGC: Self-Launch glider 'ASH 26 E', using second unique engine event time 184717 from sensor(s): ENL
# 2025-04-15 22:26:47,336 - INFO - Row 2019-10-11-LXV-2RN-01.IGC: first_event_time set to 184717 from sensor(s): ENL
# 2025-04-15 22:26:47,337 - INFO - Row 2014-08-06-NKL-0TV-01.IGC: Self-Launch glider 'DG-808 C', using second unique engine event time 222227 from sensor(s): ENL
# 2025-04-15 22:26:47,337 - INFO - Row 2014-08-06-NKL-0TV-01.IGC: first_event_time set to 222227 from sensor(s): ENL
# 2025-04-15 22:26:47,338 - INFO - Row 2019-04-21-FLA-JUM-01.IGC: Not a Self-Launch glider, using earliest engine event time 201614.
# 2025-04-15 22:26:47,338 - INFO - Row 2019-04-21-FLA-JUM-01.IGC: first_event_time set to 201614 from sensor(s): ENL
# 2025-04-15 22:26:47,339 - WARNING - Row 2019-08-23-CNI-200-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,340 - WARNING - Row 2019-06-19-CNI-27D-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,340 - WARNING - Row 2018-07-02-CNI-20B-01.IGC: Self-Launch glider 'ARCUS M' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,341 - WARNING - Row 2018-08-18-CNI-27D-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,342 - INFO - Row 2017-08-03-CNI-20Y-01.IGC: Not a Self-Launch glider, using earliest engine event time 194552.
# 2025-04-15 22:26:47,342 - INFO - Row 2017-08-03-CNI-20Y-01.IGC: first_event_time set to 194552 from sensor(s): ENL
# 2025-04-15 22:26:47,343 - WARNING - Row 2019-06-18-CNI-23Y-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,343 - WARNING - Row 2024-06-04-CNI-24W-01.IGC: No glider type information found for Gtype 'Nimeta'.
# 2025-04-15 22:26:47,344 - INFO - Row 2024-06-04-CNI-24W-01.IGC: Not a Self-Launch glider, using earliest engine event time 212653.
# 2025-04-15 22:26:47,344 - INFO - Row 2024-06-04-CNI-24W-01.IGC: first_event_time set to 212653 from sensor(s): ENL
# 2025-04-15 22:26:47,345 - WARNING - Row 2023-06-28-LXV-7EO-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,346 - INFO - Row 2019-03-08-LXV-1KO-01.IGC: Not a Self-Launch glider, using earliest engine event time 212209.
# 2025-04-15 22:26:47,348 - INFO - Row 2019-03-08-LXV-1KO-01.IGC: first_event_time set to 212209 from sensor(s): ENL
# 2025-04-15 22:26:47,349 - INFO - Row 2021-09-24-CNI-23Y-01.IGC: Self-Launch glider 'ASH 31 MI', using second unique engine event time 194028 from sensor(s): ENL
# 2025-04-15 22:26:47,349 - INFO - Row 2021-09-24-CNI-23Y-01.IGC: first_event_time set to 194028 from sensor(s): ENL
# 2025-04-15 22:26:47,350 - INFO - Row 2019-05-21-CNI-28S-01.IGC: Not a Self-Launch glider, using earliest engine event time 191513.
# 2025-04-15 22:26:47,350 - INFO - Row 2019-05-21-CNI-28S-01.IGC: first_event_time set to 191513 from sensor(s): ENL
# 2025-04-15 22:26:47,351 - INFO - Row 2024-04-27-NKL-10Q-01.IGC: Not a Self-Launch glider, using earliest engine event time 174026.
# 2025-04-15 22:26:47,351 - INFO - Row 2024-04-27-NKL-10Q-01.IGC: first_event_time set to 174026 from sensor(s): ENL
# 2025-04-15 22:26:47,352 - WARNING - Row 2018-08-17-CNI-27D-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,352 - WARNING - Row 2019-06-23-CNI-23Y-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,353 - INFO - Row 2016-05-11-CNI-20E-01.IGC: Not a Self-Launch glider, using earliest engine event time 203808.
# 2025-04-15 22:26:47,353 - INFO - Row 2016-05-11-CNI-20E-01.IGC: first_event_time set to 203808 from sensor(s): ENL
# 2025-04-15 22:26:47,354 - WARNING - Row 2017-08-02-CNI-255-01.IGC: Self-Launch glider 'VENTUS 2CXM' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,355 - INFO - Row 23IG8IJ1.IGC: Not a Self-Launch glider, using earliest engine event time 211320.
# 2025-04-15 22:26:47,355 - INFO - Row 23IG8IJ1.IGC: first_event_time set to 211320 from sensor(s): ENL
# 2025-04-15 22:26:47,356 - WARNING - Row 2021-06-18-LXV-780-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,357 - WARNING - Row 2021-04-22-CNI-21D-01.IGC: Self-Launch glider 'DG-808 C' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,357 - INFO - Row 2015-05-20-CNI-214-02.IGC: Self-Launch glider 'Taurus', using second unique engine event time 184858 from sensor(s): ENL
# 2025-04-15 22:26:47,358 - INFO - Row 2015-05-20-CNI-214-02.IGC: first_event_time set to 184858 from sensor(s): ENL
# 2025-04-15 22:26:47,358 - INFO - Row 2015-06-28-CNI-20O-01.IGC: Not a Self-Launch glider, using earliest engine event time 210807.
# 2025-04-15 22:26:47,359 - INFO - Row 2015-06-28-CNI-20O-01.IGC: first_event_time set to 210807 from sensor(s): ENL
# 2025-04-15 22:26:47,359 - WARNING - Row 44OV1OL1.IGC: Self-Launch glider 'DG-808 C' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,360 - WARNING - Row 2018-07-07-LXV-7HZ-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,362 - WARNING - Row 34NLCLO1.IGC: Self-Launch glider 'DG-808 C' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,362 - INFO - Row 2014-04-26-NKL-10Q-01.IGC: Not a Self-Launch glider, using earliest engine event time 192658.
# 2025-04-15 22:26:47,363 - INFO - Row 2014-04-26-NKL-10Q-01.IGC: first_event_time set to 192658 from sensor(s): ENL
# 2025-04-15 22:26:47,363 - WARNING - Row 2019-03-13-CNI-20B-01.IGC: Self-Launch glider 'ARCUS M' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,364 - WARNING - Row 2019-03-08-LXV-7DX-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,365 - WARNING - Row 2018-05-04-LXV-7RZ-01.IGC: Self-Launch glider 'ARCUS M' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,365 - WARNING - Row 2018-05-17-CNI-235-01.IGC: Self-Launch glider 'ASG 32 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,366 - INFO - Row 566C4OO6.IGC: Not a Self-Launch glider, using earliest engine event time 175150.
# 2025-04-15 22:26:47,367 - INFO - Row 566C4OO6.IGC: first_event_time set to 175150 from sensor(s): ENL
# 2025-04-15 22:26:47,368 - WARNING - Row 2021-06-05-CNI-27D-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,368 - WARNING - Row 2024-06-05-CNI-24W-01.IGC: No glider type information found for Gtype 'Nimeta'.
# 2025-04-15 22:26:47,369 - INFO - Row 2024-06-05-CNI-24W-01.IGC: Not a Self-Launch glider, using earliest engine event time 195709.
# 2025-04-15 22:26:47,369 - INFO - Row 2024-06-05-CNI-24W-01.IGC: first_event_time set to 195709 from sensor(s): ENL
# 2025-04-15 22:26:47,370 - INFO - Row 23IGBCA1.IGC: Self-Launch glider 'ASH 26 E', using second unique engine event time 190826 from sensor(s): ENL
# 2025-04-15 22:26:47,370 - INFO - Row 23IGBCA1.IGC: first_event_time set to 190826 from sensor(s): ENL
# 2025-04-15 22:26:47,371 - INFO - Row 2018-06-26-LXV-1OZ-01.IGC: Not a Self-Launch glider, using earliest engine event time 203020.
# 2025-04-15 22:26:47,371 - INFO - Row 2018-06-26-LXV-1OZ-01.IGC: first_event_time set to 203020 from sensor(s): ENL
# 2025-04-15 22:26:47,372 - INFO - Row 2023-08-20-CNI-295-01.IGC: Not a Self-Launch glider, using earliest engine event time 181432.
# 2025-04-15 22:26:47,372 - INFO - Row 2023-08-20-CNI-295-01.IGC: first_event_time set to 181432 from sensor(s): ENL
# 2025-04-15 22:26:47,372 - WARNING - Row 96HV7L32.IGC: Self-Launch glider 'AC-5M' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,373 - WARNING - Row 2019-06-26-CNI-23Y-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,374 - WARNING - Row 2023-08-18-CNI-25N-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,375 - INFO - Row 2013-05-17-NKL-10R-01.IGC: Not a Self-Launch glider, using earliest engine event time 165804.
# 2025-04-15 22:26:47,376 - INFO - Row 2013-05-17-NKL-10R-01.IGC: first_event_time set to 165804 from sensor(s): ENL
# 2025-04-15 22:26:47,376 - INFO - Row 2017-08-05-CNI-255-01.IGC: Self-Launch glider 'VENTUS 2CXM', using second unique engine event time 224147 from sensor(s): ENL
# 2025-04-15 22:26:47,377 - INFO - Row 2017-08-05-CNI-255-01.IGC: first_event_time set to 224147 from sensor(s): ENL
# 2025-04-15 22:26:47,377 - WARNING - Row 2015-04-23-NKL-12U-01.IGC: Self-Launch glider 'ASH 30 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,378 - WARNING - Row 2016-05-09-CNI-24Z-01.IGC: Self-Launch glider 'Antares 20E' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,379 - WARNING - Row 2014-08-02-NKL-0TV-01.IGC: Self-Launch glider 'DG-808 C' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,379 - INFO - Row 43PGDEB1.IGC: Not a Self-Launch glider, using earliest engine event time 171336.
# 2025-04-15 22:26:47,380 - INFO - Row 43PGDEB1.IGC: first_event_time set to 171336 from sensor(s): ENL
# 2025-04-15 22:26:47,380 - INFO - Row 2012-05-18-NKL-10R-01.IGC: Not a Self-Launch glider, using earliest engine event time 162606.
# 2025-04-15 22:26:47,381 - INFO - Row 2012-05-18-NKL-10R-01.IGC: first_event_time set to 162606 from sensor(s): ENL
# 2025-04-15 22:26:47,381 - WARNING - Row 2021-03-19-LXV-AGO-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,382 - WARNING - Row 181G8KM1.IGC: Self-Launch glider 'DG-400' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,383 - WARNING - Row 2015-06-01-CNI-21D-01.IGC: Self-Launch glider 'DG-808 C' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,384 - WARNING - Row 2019-03-13-LXV-7CD-01.IGC: Self-Launch glider 'ASH 26 E' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,384 - WARNING - Row 2021-06-05-FLA-JEU-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,385 - INFO - Row 2015-04-23-CNI-20Y-01.IGC: Not a Self-Launch glider, using earliest engine event time 200848.
# 2025-04-15 22:26:47,386 - INFO - Row 2015-04-23-CNI-20Y-01.IGC: first_event_time set to 200848 from sensor(s): ENL
# 2025-04-15 22:26:47,387 - WARNING - Row 2021-06-17-NAV-8QQ-01.IGC: Self-Launch glider 'DG-808 C' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,387 - WARNING - Row 46HGA9D1.IGC: Self-Launch glider 'VENTUS 3M' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,388 - INFO - Row 2024-06-07-CNI-29F-01.IGC: Not a Self-Launch glider, using earliest engine event time 182209.
# 2025-04-15 22:26:47,389 - INFO - Row 2024-06-07-CNI-29F-01.IGC: first_event_time set to 182209 from sensor(s): ENL
# 2025-04-15 22:26:47,389 - WARNING - Row 13CLCLO1.IGC: Self-Launch glider 'DG-808 C' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,390 - WARNING - Row 2017-10-10-LXV-2RN-01.IGC: Self-Launch glider 'ASH 26 E' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,391 - WARNING - Row 562LCS71.IGC: Self-Launch glider 'SILENT-IN' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,391 - INFO - Row 2023-05-21-CNI-295-01.IGC: Not a Self-Launch glider, using earliest engine event time 183726.
# 2025-04-15 22:26:47,392 - INFO - Row 2023-05-21-CNI-295-01.IGC: first_event_time set to 183726 from sensor(s): ENL
# 2025-04-15 22:26:47,392 - WARNING - Row 2018-05-17-LXV-7H2-01.IGC: Self-Launch glider 'ARCUS M' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,393 - WARNING - Row 2016-08-09-CNI-22M-01.IGC: Self-Launch glider 'ARCUS M' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,394 - INFO - Row 2016-04-19-CNI-21U-01.IGC: Not a Self-Launch glider, using earliest engine event time 175005.
# 2025-04-15 22:26:47,394 - INFO - Row 2016-04-19-CNI-21U-01.IGC: first_event_time set to 175005 from sensor(s): ENL
# 2025-04-15 22:26:47,395 - WARNING - Row 2024-06-01-CNI-0XG-01.IGC: Self-Launch glider 'ARCUS M' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,396 - WARNING - Row 46PG8KM2.IGC: Self-Launch glider 'DG-400' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,397 - WARNING - Row 2024-06-03-CNI-23Y-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,398 - INFO - Row 2016-05-25-CNI-214-01.IGC: Self-Launch glider 'Taurus', using second unique engine event time 192440 from sensor(s): ENL
# 2025-04-15 22:26:47,398 - INFO - Row 2016-05-25-CNI-214-01.IGC: first_event_time set to 192440 from sensor(s): ENL
# 2025-04-15 22:26:47,399 - WARNING - Row 2024-08-03-CNI-23Y-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,400 - WARNING - Row 2021-04-20-LXV-81T-01.IGC: Self-Launch glider 'SILENT 2 ELECTRO' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,400 - INFO - Row 2017-08-09-CNI-20Y-01.IGC: Not a Self-Launch glider, using earliest engine event time 225407.
# 2025-04-15 22:26:47,401 - INFO - Row 2017-08-09-CNI-20Y-01.IGC: first_event_time set to 225407 from sensor(s): ENL
# 2025-04-15 22:26:47,401 - INFO - Row 2010-08-06-NKL-0W2-01.IGC: Not a Self-Launch glider, using earliest engine event time 184956.
# 2025-04-15 22:26:47,402 - INFO - Row 2010-08-06-NKL-0W2-01.IGC: first_event_time set to 184956 from sensor(s): ENL
# 2025-04-15 22:26:47,402 - WARNING - Row 2024-06-04-CNI-23Y-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,403 - WARNING - Row 46OG8KM1.IGC: Self-Launch glider 'DG-400' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,404 - WARNING - Row 2020-03-13-CNI-235-01.IGC: Self-Launch glider 'ASG 32 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,404 - INFO - Row 2018-05-15-CNI-27P-01.IGC: Not a Self-Launch glider, using earliest engine event time 181822.
# 2025-04-15 22:26:47,405 - INFO - Row 2018-05-15-CNI-27P-01.IGC: first_event_time set to 181822 from sensor(s): ENL
# 2025-04-15 22:26:47,405 - INFO - Row 2014-05-17-NKL-10R-01.IGC: Not a Self-Launch glider, using earliest engine event time 171141.
# 2025-04-15 22:26:47,406 - INFO - Row 2014-05-17-NKL-10R-01.IGC: first_event_time set to 171141 from sensor(s): ENL
# 2025-04-15 22:26:47,406 - WARNING - Row 2023-08-25-CNI-25N-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,407 - INFO - Row 99FGJUM1.IGC: Not a Self-Launch glider, using earliest engine event time 201248.
# 2025-04-15 22:26:47,407 - INFO - Row 99FGJUM1.IGC: first_event_time set to 201248 from sensor(s): ENL
# 2025-04-15 22:26:47,408 - WARNING - Row 2023-08-21-CNI-25N-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,409 - WARNING - Row 25JC48C2.IGC: Self-Launch glider 'ASH 26 E' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,410 - WARNING - Row 2019-08-10-CNI-28V-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,410 - WARNING - Row 479C4FR2.IGC: No glider type information found for Gtype 'PIK20E'.
# 2025-04-15 22:26:47,411 - INFO - Row 479C4FR2.IGC: Not a Self-Launch glider, using earliest engine event time 193550.
# 2025-04-15 22:26:47,412 - INFO - Row 479C4FR2.IGC: first_event_time set to 193550 from sensor(s): ENL
# 2025-04-15 22:26:47,412 - WARNING - Row 2015-06-07-CNI-V8R-01.IGC: Self-Launch glider 'DG-400' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,413 - INFO - Row 17UGAA51.IGC: Not a Self-Launch glider, using earliest engine event time 182811.
# 2025-04-15 22:26:47,413 - INFO - Row 17UGAA51.IGC: first_event_time set to 182811 from sensor(s): ENL
# 2025-04-15 22:26:47,414 - WARNING - Row 2021-06-04-FLA-JEU-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,415 - INFO - Row 2019-04-21-LXV-7R1-01.IGC: Not a Self-Launch glider, using earliest engine event time 200426.
# 2025-04-15 22:26:47,415 - INFO - Row 2019-04-21-LXV-7R1-01.IGC: first_event_time set to 200426 from sensor(s): ENL
# 2025-04-15 22:26:47,416 - WARNING - Row 2018-08-19-CNI-232-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,416 - WARNING - Row 2021-06-13-CNI-235-01.IGC: Self-Launch glider 'ASG 32 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,417 - INFO - Row 2019-10-09-CNI-28S-01.IGC: Not a Self-Launch glider, using earliest engine event time 190233.
# 2025-04-15 22:26:47,418 - INFO - Row 2019-10-09-CNI-28S-01.IGC: first_event_time set to 190233 from sensor(s): ENL
# 2025-04-15 22:26:47,418 - INFO - Row 2021-06-10-CNI-20E-01.IGC: Not a Self-Launch glider, using earliest engine event time 185216.
# 2025-04-15 22:26:47,418 - INFO - Row 2021-06-10-CNI-20E-01.IGC: first_event_time set to 185216 from sensor(s): ENL
# 2025-04-15 22:26:47,419 - WARNING - Row 2023-06-03-LXV-ABC-01.IGC: Self-Launch glider 'ARCUS M' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,420 - INFO - Row 183G8KM1.IGC: Self-Launch glider 'DG-400', using second unique engine event time 212627 from sensor(s): ENL
# 2025-04-15 22:26:47,420 - INFO - Row 183G8KM1.IGC: first_event_time set to 212627 from sensor(s): ENL
# 2025-04-15 22:26:47,421 - WARNING - Row 24HLCLO1.IGC: Self-Launch glider 'DG-808 C' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,422 - INFO - Row 2013-08-03-NKL-12K-01.IGC: Self-Launch glider 'DG-808 C', using second unique engine event time 162630 from sensor(s): ENL
# 2025-04-15 22:26:47,422 - INFO - Row 2013-08-03-NKL-12K-01.IGC: first_event_time set to 162630 from sensor(s): ENL
# 2025-04-15 22:26:47,423 - INFO - Row 2023-05-25-CNI-295-01.IGC: Not a Self-Launch glider, using earliest engine event time 203117.
# 2025-04-15 22:26:47,423 - INFO - Row 2023-05-25-CNI-295-01.IGC: first_event_time set to 203117 from sensor(s): ENL
# 2025-04-15 22:26:47,424 - INFO - Row 2014-04-22-NKL-10Q-01.IGC: Not a Self-Launch glider, using earliest engine event time 201610.
# 2025-04-15 22:26:47,424 - INFO - Row 2014-04-22-NKL-10Q-01.IGC: first_event_time set to 201610 from sensor(s): ENL
# 2025-04-15 22:26:47,425 - WARNING - Row 2019-03-08-CNI-27K-01.IGC: Self-Launch glider 'DG-808 C' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,425 - INFO - Row 46HG1531.IGC: Not a Self-Launch glider, using earliest engine event time 204745.
# 2025-04-15 22:26:47,425 - INFO - Row 46HG1531.IGC: first_event_time set to 204745 from sensor(s): ENL
# 2025-04-15 22:26:47,426 - INFO - Row 2016-09-23-CNI-20E-01.IGC: Not a Self-Launch glider, using earliest engine event time 201651.
# 2025-04-15 22:26:47,426 - INFO - Row 2016-09-23-CNI-20E-01.IGC: first_event_time set to 201651 from sensor(s): ENL
# 2025-04-15 22:26:47,427 - INFO - Row 13CGIQO1.IGC: Not a Self-Launch glider, using earliest engine event time 173156.
# 2025-04-15 22:26:47,427 - INFO - Row 13CGIQO1.IGC: first_event_time set to 173156 from sensor(s): ENL
# 2025-04-15 22:26:47,428 - WARNING - Row 2017-03-10-LXV-7DX-01.IGC: Self-Launch glider 'ASH 31 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,429 - WARNING - Row 2021-10-03-LXV-7GT-01.IGC: Self-Launch glider 'ASH 26 E' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,430 - INFO - Row 2024-06-07-CNI-20E-01.IGC: Not a Self-Launch glider, using earliest engine event time 165050.
# 2025-04-15 22:26:47,430 - INFO - Row 2024-06-07-CNI-20E-01.IGC: first_event_time set to 165050 from sensor(s): ENL
# 2025-04-15 22:26:47,431 - INFO - Row 2017-03-16-CNI-22G-01.IGC: Self-Launch glider 'ASH 30 MI', using second unique engine event time 182846 from sensor(s): ENL
# 2025-04-15 22:26:47,431 - INFO - Row 2017-03-16-CNI-22G-01.IGC: first_event_time set to 182846 from sensor(s): ENL
# 2025-04-15 22:26:47,432 - WARNING - Row 2014-08-07-NKL-0TV-01.IGC: Self-Launch glider 'DG-808 C' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:47,432 - INFO - Row 2017-09-18-CNI-20Y-01.IGC: Not a Self-Launch glider, using earliest engine event time 181629.
# 2025-04-15 22:26:47,433 - INFO - Row 2017-09-18-CNI-20Y-01.IGC: first_event_time set to 181629 from sensor(s): ENL
# 2025-04-15 22:26:47,433 - WARNING - Row 2024-06-09-CNI-24W-01.IGC: No glider type information found for Gtype 'Nimeta'.
# 2025-04-15 22:26:47,434 - INFO - Row 2024-06-09-CNI-24W-01.IGC: Not a Self-Launch glider, using earliest engine event time 195546.
# 2025-04-15 22:26:47,434 - INFO - Row 2024-06-09-CNI-24W-01.IGC: first_event_time set to 195546 from sensor(s): ENL
# ...
# 2025-04-15 22:26:48,120 - WARNING - Row 4536-9241100361.igc: No glider type information found for Gtype 'JS-5'.
# 2025-04-15 22:26:48,120 - INFO - Row 4536-9241100361.igc: Not a Self-Launch glider, using earliest engine event time 225515.
# 2025-04-15 22:26:48,120 - INFO - Row 4536-9241100361.igc: first_event_time set to 225515 from sensor(s): MOP
# 2025-04-15 22:26:48,121 - WARNING - Row 4536-9240051790.igc: Self-Launch glider 'ASG 32 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,122 - WARNING - Row 4536-9239003145.igc: Self-Launch glider 'VENTUS 3M' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,122 - WARNING - Row 4536-9240051990.igc: Self-Launch glider 'ARCUS M' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,123 - WARNING - Row 4536-9240051880.igc: Self-Launch glider 'ARCUS M' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,124 - WARNING - Row 4536-9240051974.igc: Self-Launch glider 'ARCUS M' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,125 - WARNING - Row 4536-9241100413.igc: Self-Launch glider 'EB29R' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,125 - WARNING - Row 4536-9240051766.igc: Self-Launch glider 'ARCUS M' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,126 - INFO - Row 4536-9239003649.igc: Not a Self-Launch glider, using earliest engine event time 204632.
# 2025-04-15 22:26:48,126 - INFO - Row 4536-9239003649.igc: first_event_time set to 204632 from sensor(s): MOP
# 2025-04-15 22:26:48,127 - WARNING - Row 4536-9240051948.igc: Self-Launch glider 'Twinshark' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,128 - WARNING - Row 4536-9240051728.igc: Self-Launch glider 'ARCUS M' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,128 - INFO - Row 4536-9241100557.igc: Self-Launch glider 'ASH30 NIXUS', using second unique engine event time 210413 from sensor(s): ENL
# 2025-04-15 22:26:48,129 - INFO - Row 4536-9241100557.igc: first_event_time set to 210413 from sensor(s): ENL
# 2025-04-15 22:26:48,129 - INFO - Row 4536-9239003625.igc: Not a Self-Launch glider, using earliest engine event time 202201.
# 2025-04-15 22:26:48,130 - INFO - Row 4536-9239003625.igc: first_event_time set to 202201 from sensor(s): ENL
# 2025-04-15 22:26:48,130 - INFO - Row 4536-9239003521.igc: Not a Self-Launch glider, using earliest engine event time 180006.
# 2025-04-15 22:26:48,131 - INFO - Row 4536-9239003521.igc: first_event_time set to 180006 from sensor(s): MOP
# 2025-04-15 22:26:48,131 - WARNING - Row 4536-9240051864.igc: Self-Launch glider 'ARCUS M' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,132 - INFO - Row 4536-9239003415.igc: Not a Self-Launch glider, using earliest engine event time 193832.
# 2025-04-15 22:26:48,134 - INFO - Row 4536-9239003415.igc: first_event_time set to 193832 from sensor(s): ENL
# 2025-04-15 22:26:48,135 - WARNING - Row 4536-9241100603.igc: Self-Launch glider 'EB29R' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,136 - WARNING - Row 4536-9240051759.igc: Self-Launch glider 'ARCUS M' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,137 - WARNING - Row 4536-9240051778.igc: Self-Launch glider 'ARCUS M' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,137 - WARNING - Row 4536-9241100430.igc: Self-Launch glider 'EB29R' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,138 - WARNING - Row 4536-9241100328.igc: Self-Launch glider 'EB29R' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,139 - WARNING - Row 4536-9240051735.igc: Self-Launch glider 'ASG 32 MI' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,139 - WARNING - Row 4536-9241100372.igc: Self-Launch glider 'EB29R' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,140 - INFO - Row 4536-9239003361.igc: Not a Self-Launch glider, using earliest engine event time 180114.
# 2025-04-15 22:26:48,140 - INFO - Row 4536-9239003361.igc: first_event_time set to 180114 from sensor(s): MOP
# 2025-04-15 22:26:48,141 - WARNING - Row 4536-9240051818.igc: Self-Launch glider 'ARCUS M' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,142 - WARNING - Row 4536-9241100438.igc: Self-Launch glider 'ASH30 NIXUS' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,142 - WARNING - Row 4536-9241100574.igc: Self-Launch glider 'ASH30 NIXUS' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,143 - WARNING - Row 4536-9241100591.igc: Self-Launch glider 'ASH30 NIXUS' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,144 - WARNING - Row 4536-9240051894.igc: Self-Launch glider 'ARCUS M' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,145 - WARNING - Row 4536-9241100382.igc: Self-Launch glider 'EB29R' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,145 - INFO - Row 4536-9241100489.igc: Self-Launch glider 'ASH30 NIXUS', using second unique engine event time 183218 from sensor(s): ENL
# 2025-04-15 22:26:48,146 - INFO - Row 4536-9241100489.igc: first_event_time set to 183218 from sensor(s): ENL
# 2025-04-15 22:26:48,146 - INFO - Row 4536-9240051954.igc: Self-Launch glider 'ARCUS M', using second unique engine event time 205007 from sensor(s): ENL
# 2025-04-15 22:26:48,147 - INFO - Row 4536-9240051954.igc: first_event_time set to 205007 from sensor(s): ENL
# 2025-04-15 22:26:48,147 - WARNING - Row 4536-9240051862.igc: Self-Launch glider 'ARCUS M' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,148 - INFO - Row 4536-9239003543.igc: Not a Self-Launch glider, using earliest engine event time 185201.
# 2025-04-15 22:26:48,148 - INFO - Row 4536-9239003543.igc: first_event_time set to 185201 from sensor(s): ENL
# 2025-04-15 22:26:48,149 - WARNING - Row 4536-9240051976.igc: Self-Launch glider 'ARCUS M' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,150 - WARNING - Row 4536-9241100565.igc: No glider type information found for Gtype 'JS-5'.
# 2025-04-15 22:26:48,150 - INFO - Row 4536-9241100565.igc: Not a Self-Launch glider, using earliest engine event time 202808.
# 2025-04-15 22:26:48,150 - INFO - Row 4536-9241100565.igc: first_event_time set to 202808 from sensor(s): MOP
# 2025-04-15 22:26:48,151 - INFO - Row 4536-9239003447.igc: Not a Self-Launch glider, using earliest engine event time 191638.
# 2025-04-15 22:26:48,151 - INFO - Row 4536-9239003447.igc: first_event_time set to 191638 from sensor(s): ENL
# 2025-04-15 22:26:48,152 - WARNING - Row 4536-9241100447.igc: Self-Launch glider 'EB29R' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,153 - WARNING - Row 4536-9241100387.igc: Self-Launch glider 'ASH30 NIXUS' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,153 - WARNING - Row 4536-9240051916.igc: Self-Launch glider 'Twinshark' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,154 - WARNING - Row 4536-9241100549.igc: Self-Launch glider 'EB29R' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,156 - INFO - Row 4536-9239003479.igc: Not a Self-Launch glider, using earliest engine event time 185638.
# 2025-04-15 22:26:48,157 - INFO - Row 4536-9239003479.igc: first_event_time set to 185638 from sensor(s): ENL
# 2025-04-15 22:26:48,157 - INFO - Row 4536-9240051962.igc: Self-Launch glider 'ARCUS M', using second unique engine event time 195301 from sensor(s): ENL
# 2025-04-15 22:26:48,158 - INFO - Row 4536-9240051962.igc: first_event_time set to 195301 from sensor(s): ENL
# 2025-04-15 22:26:48,158 - WARNING - Row 4536-9241100356.igc: No glider type information found for Gtype 'JS-5'.
# 2025-04-15 22:26:48,159 - INFO - Row 4536-9241100356.igc: Not a Self-Launch glider, using earliest engine event time 210416.
# 2025-04-15 22:26:48,159 - INFO - Row 4536-9241100356.igc: first_event_time set to 210416 from sensor(s): MOP
# 2025-04-15 22:26:48,159 - WARNING - Row 4536-9241100370.igc: Self-Launch glider 'ASH30 NIXUS' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,160 - INFO - Row 4536-9239003287.igc: Not a Self-Launch glider, using earliest engine event time 190710.
# 2025-04-15 22:26:48,161 - INFO - Row 4536-9239003287.igc: first_event_time set to 190710 from sensor(s): ENL
# 2025-04-15 22:26:48,161 - WARNING - Row 4536-9240051928.igc: Self-Launch glider 'ARCUS M' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,162 - WARNING - Row 4536-9240051942.igc: Self-Launch glider 'ARCUS M' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,163 - WARNING - Row 4536-9241100535.igc: Self-Launch glider 'EB29R' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,163 - INFO - Row 4536-9240051967.igc: Self-Launch glider 'ARCUS M', using second unique engine event time 195036 from sensor(s): ENL
# 2025-04-15 22:26:48,164 - INFO - Row 4536-9240051967.igc: first_event_time set to 195036 from sensor(s): ENL
# 2025-04-15 22:26:48,164 - WARNING - Row 4536-9240051996.igc: Self-Launch glider 'Twinshark' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,165 - WARNING - Row 4536-9240051920.igc: Self-Launch glider 'ARCUS M' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,166 - INFO - Row 4536-9239003297.igc: Not a Self-Launch glider, using earliest engine event time 175457.
# 2025-04-15 22:26:48,166 - INFO - Row 4536-9239003297.igc: first_event_time set to 175457 from sensor(s): MOP
# 2025-04-15 22:26:48,167 - INFO - Row 4536-9239003703.igc: Not a Self-Launch glider, using earliest engine event time 180442.
# 2025-04-15 22:26:48,167 - INFO - Row 4536-9239003703.igc: first_event_time set to 180442 from sensor(s): ENL
# 2025-04-15 22:26:48,168 - INFO - Row 4536-9240051965.igc: Self-Launch glider 'ARCUS M', using second unique engine event time 202517 from sensor(s): ENL
# 2025-04-15 22:26:48,168 - INFO - Row 4536-9240051965.igc: first_event_time set to 202517 from sensor(s): ENL
# 2025-04-15 22:26:48,169 - WARNING - Row 4536-9240051752.igc: Self-Launch glider 'ARCUS M' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,171 - WARNING - Row 4536-9241100423.igc: Self-Launch glider 'EB29R' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,171 - WARNING - Row 4536-9241100559.igc: Self-Launch glider 'EB29R' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,172 - WARNING - Row 4536-9240051914.igc: Self-Launch glider 'ARCUS M' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,173 - INFO - Row 4536-9240051968.igc: Self-Launch glider 'ARCUS M', using second unique engine event time 194839 from sensor(s): ENL
# 2025-04-15 22:26:48,173 - INFO - Row 4536-9240051968.igc: first_event_time set to 194839 from sensor(s): ENL
# 2025-04-15 22:26:48,174 - WARNING - Row 4536-9240051946.igc: Self-Launch glider 'ARCUS M' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,175 - WARNING - Row 4536-9240051792.igc: Self-Launch glider 'ARCUS M' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,175 - WARNING - Row 4536-9240051882.igc: Self-Launch glider 'ARCUS M' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,176 - WARNING - Row 4536-9241100353.igc: Self-Launch glider 'ASH30 NIXUS' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,177 - WARNING - Row 4536-9240051910.igc: Self-Launch glider 'ARCUS M' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,178 - WARNING - Row 4536-9240051884.igc: Self-Launch glider 'Twinshark' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,179 - WARNING - Row 4536-9241100474.igc: Self-Launch glider 'EB29R' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,179 - WARNING - Row 4536-9240051919.igc: Self-Launch glider 'ARCUS M' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,180 - WARNING - Row 4536-9240051856.igc: Self-Launch glider 'ARCUS M' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,181 - WARNING - Row 4536-9241100464.igc: Self-Launch glider 'EB29R' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,182 - WARNING - Row 4536-9241100525.igc: Self-Launch glider 'EB29R' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,183 - WARNING - Row 4536-9240051964.igc: Self-Launch glider 'Twinshark' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,183 - WARNING - Row 4536-9240051868.igc: Self-Launch glider 'Twinshark' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,184 - WARNING - Row 4536-9240051715.igc: Self-Launch glider 'ARCUS M' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,185 - WARNING - Row 4536-9240051814.igc: Self-Launch glider 'ARCUS M' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,186 - INFO - Row 4536-9239003457.igc: Not a Self-Launch glider, using earliest engine event time 191717.
# 2025-04-15 22:26:48,186 - INFO - Row 4536-9239003457.igc: first_event_time set to 191717 from sensor(s): MOP
# 2025-04-15 22:26:48,187 - WARNING - Row 4536-9239003265.igc: Self-Launch glider 'VENTUS 3M' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,188 - WARNING - Row 4536-9240051798.igc: Self-Launch glider 'ARCUS M' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,188 - INFO - Row 4536-9239003632.igc: Not a Self-Launch glider, using earliest engine event time 211525.
# 2025-04-15 22:26:48,189 - INFO - Row 4536-9239003632.igc: first_event_time set to 211525 from sensor(s): ENL
# 2025-04-15 22:26:48,189 - INFO - Row 4536-9239003653.igc: Not a Self-Launch glider, using earliest engine event time 202732.
# 2025-04-15 22:26:48,190 - INFO - Row 4536-9239003653.igc: first_event_time set to 202732 from sensor(s): ENL
# 2025-04-15 22:26:48,190 - WARNING - Row 4536-9240051930.igc: Self-Launch glider 'ARCUS M' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,191 - WARNING - Row 4536-9240051771.igc: Self-Launch glider 'ARCUS M' has fewer than two unique engine run events. Leaving event columns blank.
# 2025-04-15 22:26:48,192 - INFO - Row 4536-9241100566.igc: Self-Launch glider 'EB29R', using second unique engine event time 211140 from sensor(s): ENL
# 2025-04-15 22:26:48,192 - INFO - Row 4536-9241100566.igc: first_event_time set to 211140 from sensor(s): ENL

# %%
# Convert first_event_time to datetime
df['first_event_datetime'] = df.apply(convert_to_datetime, axis=1)
df['flight_start_datetime'] = df['Start Time'].apply(lambda x: datetime.strptime(str(x), '%H%M%S'))

# Now define the 5-minute window using both columns
df[['window_start', 'window_end']] = df.apply(
    lambda row: pd.Series(define_time_window(row['first_event_datetime'], row['flight_start_datetime'], window_minutes=5)),
    axis=1
)

# %%
S2H = 3600          # Seconds to Hours
M2F = 3.28084       # Meters to Feet
K2M = 0.621371

# %%
def process_single_flight_non_speed(idx, row):
    """
    Processes a flight row to compute all non-speed engine run metrics.
    This version does NOT compute the TAS statistics.
    It returns a dictionary with:
      - engine_run_agls
      - altitude_rate_pre_event_window (ft/s)
      - distance_traveled_during_window (miles)
      - is_circling_during_pre_event_window
      - terrain_elev_at_engine_run (ft)
      - terrain_label_at_engine_run
      - Engine_Start_Above_1000ft
      - engine_run_times (s)
      - height_gain_loss (ft)
    Speed columns will be left blank.
    """
    ensure_ee_initialized()
    results = {'index': idx}
    results.update({
        'engine_run_agls': "",
        'altitude_rate_pre_event_window (ft/s)': "",
        'distance_traveled_during_window (miles)': "",
        'is_circling_during_pre_event_window': "",
        'terrain_elev_at_engine_run (ft)': "",
        'terrain_label_at_engine_run': "",
        'Engine_Start_Above_1000ft': "",
        'engine_run_times (s)': "",
        'height_gain_loss (ft)': "",
        # Leave speed columns blank for now.
        'avg_speed_while_engine_running (knots)': "",
        'min_speed_while_engine_running (knots)': "",
        'max_speed_while_engine_running (knots)': ""
    })
    
    try:
        flight_file = row['File']
        flight_id = Path(flight_file).stem
        df_flight = load_flight_data(flight_id, row.get('Date (MM/DD/YYYY)', ''))
        if df_flight is None or df_flight.empty:
            return results
        flight_start_dt = row['flight_start_datetime']
        
        # Determine which engine run start time column to use.
        if pd.notnull(row.get('ENL_Engine_Run_Start_Times', "")) and str(row['ENL_Engine_Run_Start_Times']).strip() != "":
            run_times_str = row['ENL_Engine_Run_Start_Times']
            alt_col = 'ENL_Engine_Run_Altitudes_AGL'
        elif pd.notnull(row.get('MOP_Engine_Run_Start_Times', "")) and str(row['MOP_Engine_Run_Start_Times']).strip() != "":
            run_times_str = row['MOP_Engine_Run_Start_Times']
            alt_col = 'MOP_Engine_Run_Altitudes_AGL'
        elif pd.notnull(row.get('RPM_Engine_Run_Start_Times', "")) and str(row['RPM_Engine_Run_Start_Times']).strip() != "":
            run_times_str = row['RPM_Engine_Run_Start_Times']
            alt_col = 'RPM_Engine_Run_Altitudes_AGL'
        else:
            run_times_str = ""
            alt_col = None
        if run_times_str == "":
            return results
        
        run_times_list = [rt.strip() for rt in run_times_str.split(",") if rt.strip()]
        if alt_col and pd.notnull(row.get(alt_col, "")):
            altitude_values_list = [val.strip() for val in str(row.get(alt_col, "")).split(",") if val.strip()]
        else:
            altitude_values_list = []
        
        engine_run_agls = []
        run_alt_rate = []
        run_distance = []
        run_circling = []
        engine_run_terrain_elevs = []
        engine_run_terrain_labels = []
        engine_run_above_1000 = []
        
        for i, rt in enumerate(run_times_list):
            try:
                event_dt = datetime.strptime(row['Date (MM/DD/YYYY)'] + ' ' + rt, '%m/%d/%Y %H%M%S')
            except Exception as e:
                logging.warning(f"Error parsing engine run datetime for flight '{flight_file}', token {rt}: {e}")
                continue
            window_start, window_end = define_time_window(event_dt, flight_start_dt, window_minutes=5)
            mask = (df_flight['timestamp'] >= window_start) & (df_flight['timestamp'] <= window_end)
            df_window = df_flight.loc[mask]
            if not df_window.empty:
                try:
                    alt_rate = calculate_descent_rate(df_window, window_start, window_end)
                except Exception as e:
                    logging.warning(f"Flight '{flight_file}', engine run {i}: error computing altitude rate: {e}")
                    alt_rate = pd.NA
                run_alt_rate.append(str(alt_rate) if pd.notna(alt_rate) else "")
                
                try:
                    dist = calculate_distance_traveled(df_window, window_start, window_end)
                except Exception as e:
                    logging.warning(f"Flight '{flight_file}', engine run {i}: error computing distance traveled: {e}")
                    dist = pd.NA
                run_distance.append(str(dist) if pd.notna(dist) else "")
                
                try:
                    circling = detect_circling_behavior(df_window, window_start, window_end)
                except Exception as e:
                    logging.warning(f"Flight '{flight_file}', engine run {i}: error detecting circling: {e}")
                    circling = ""
                run_circling.append(str(circling))
                
                df_flight['time_diff'] = (df_flight['timestamp'] - event_dt).abs()
                try:
                    event_row = df_flight.loc[df_flight['time_diff'].idxmin()]
                except Exception as e:
                    logging.warning(f"Flight '{flight_file}', engine run {i}: error finding closest event row: {e}")
                    event_row = None
            else:
                run_alt_rate.append("")
                run_distance.append("")
                run_circling.append("")
                event_row = None
            
            if i < len(altitude_values_list):
                eng_agl = altitude_values_list[i]
            else:
                eng_agl = pd.NA
            engine_run_agls.append(str(eng_agl))
            
            try:
                if pd.notna(eng_agl) and str(eng_agl).strip() != "":
                    engine_run_above_1000.append("True" if float(eng_agl) > 1000 else "False")
                else:
                    engine_run_above_1000.append("")
            except Exception as e:
                logging.warning(f"Flight '{flight_file}', engine run {i}: error computing Engine_Start_Above_1000ft: {e}")
                engine_run_above_1000.append("")
            
            if event_row is not None:
                try:
                    event_lat = event_row['latitude']
                    event_lon = event_row['longitude']
                    terrain_elev_m = get_dem_elevation_gee(event_lat, event_lon)
                    if terrain_elev_m is not None and isinstance(terrain_elev_m, (int, float)) and not np.isnan(terrain_elev_m):
                        terrain_elev_ft = terrain_elev_m * M2F
                    else:
                        terrain_elev_ft = pd.NA
                except Exception as e:
                    logging.warning(f"Flight '{flight_file}', engine run {i}: error retrieving terrain elevation: {e}")
                    terrain_elev_ft = pd.NA
                engine_run_terrain_elevs.append(str(terrain_elev_ft) if pd.notna(terrain_elev_ft) else "")
                
                try:
                    terrain_label = get_terrain_label_at_first_engine_event_gee(event_lat, event_lon)
                    engine_run_terrain_labels.append(terrain_label if terrain_label else "")
                except Exception as e:
                    logging.warning(f"Flight '{flight_file}', engine run {i}: error retrieving terrain label: {e}")
                    engine_run_terrain_labels.append("")
            else:
                engine_run_terrain_elevs.append("")
                engine_run_terrain_labels.append("")
        
        # Store non-speed per-engine-run metrics as comma-separated strings.
        results['engine_run_agls'] = ",".join(engine_run_agls)
        results['altitude_rate_pre_event_window (ft/s)'] = ",".join(run_alt_rate)
        results['distance_traveled_during_window (miles)'] = ",".join(run_distance)
        results['is_circling_during_pre_event_window'] = ",".join(run_circling)
        results['terrain_elev_at_engine_run (ft)'] = ",".join(engine_run_terrain_elevs)
        results['terrain_label_at_engine_run'] = ",".join(engine_run_terrain_labels)
        results['Engine_Start_Above_1000ft'] = ",".join(engine_run_above_1000)
        
        # Process engine run times and height gain/loss.
        sensor_info = row.get("Sensor Info", "")
        event_sensor = row.get("event_sensor", "")
        engine_run_times, height_gains = parse_engine_run_info(sensor_info, sensor=event_sensor)
        results["engine_run_times (s)"] = ",".join(str(x) for x in engine_run_times)
        results["height_gain_loss (ft)"] = height_gains
        
    except Exception as e:
        logging.warning(f"General error processing flight {idx}: {e}")
    
    return results

# %%
logging.basicConfig(level=logging.WARNING, format='%(levelname)s: %(message)s')
logger = logging.getLogger()

# %%
ee.Authenticate()
# Out:
# True

# %%
import csv

# %%
# =============================================================================
# Stage 1 Main Block: Process Non-Speed Columns
# =============================================================================
if __name__ == '__main__':
    logging.info("Starting Stage 1: Processing non-speed columns...")
    
    
    # Ensure required columns exist; for example, "flight_start_datetime" must have been computed earlier.
    # (Add your pre-processing step here if needed.)
    
    # Process each flight in parallel, computing non-speed columns.
    flight_rows = list(df.iterrows())
    results_list = Parallel(n_jobs=-1, verbose=5)(
        delayed(process_single_flight_non_speed)(idx, row) for idx, row in flight_rows
    )
    results_df = pd.DataFrame(results_list)
    
    # Make sure "index" is present in both DataFrames.
    if "index" not in df.columns:
        df = df.reset_index()
    if "index" not in results_df.columns:
        results_df = results_df.reset_index()
    
    # List of non-speed new columns.
    new_columns = [
        "engine_run_agls",
        "altitude_rate_pre_event_window (ft/s)",
        "distance_traveled_during_window (miles)",
        "is_circling_during_pre_event_window",
        "terrain_elev_at_engine_run (ft)",
        "terrain_label_at_engine_run",
        "Engine_Start_Above_1000ft",
        "engine_run_times (s)",
        "height_gain_loss (ft)"
    ]
    missing_cols = [col for col in new_columns if col not in results_df.columns]
    if missing_cols:
        logging.warning(f"Missing non-speed columns in results_df: {missing_cols}")
    
    # Merge non-speed computed results back into the main DataFrame.
    df = df.merge(results_df, on="index", how="outer")
    
    # Save intermediate DataFrame without speed columns.
    #df.to_csv("flights_final_without_speed.csv", sep="\t", index=False, quoting=csv.QUOTE_ALL)
    logging.info("✅ Stage 1 complete: Non-speed columns saved as flights_final_without_speed.csv")
    
    # =============================================================================
    # Stage 2: Process Speed Columns Separately
    # =============================================================================
    logging.info("Starting Stage 2: Processing speed columns...")
    
    # Prepare lists to collect speed values.
    avg_speed_list = []
    min_speed_list = []
    max_speed_list = []
    
    # Iterate through each row in the now updated df.
    for idx, row in df.iterrows():
        try:
            # Now that "engine_run_times (s)" exists in df, we can compute TAS stats.
            tas_stats = get_true_airspeed_stats_for_engine_runs_from_row(row, debug=False)
            if tas_stats and len(tas_stats) > 0:
                avg_speeds = [f"{avg:.2f}" for (_, avg, _, _) in tas_stats]
                min_speeds = [f"{min_val:.2f}" for (_, _, min_val, _) in tas_stats]
                max_speeds = [f"{max_val:.2f}" for (_, _, _, max_val) in tas_stats]
                avg_speed_list.append(",".join(avg_speeds))
                min_speed_list.append(",".join(min_speeds))
                max_speed_list.append(",".join(max_speeds))
            else:
                avg_speed_list.append("")
                min_speed_list.append("")
                max_speed_list.append("")
        except Exception as e:
            logging.warning(f"Error processing speed for row {idx}: {e}")
            avg_speed_list.append("")
            min_speed_list.append("")
            max_speed_list.append("")
    
    # Insert the speed columns into df.
    df["avg_speed_while_engine_running (knots)"] = avg_speed_list
    df["min_speed_while_engine_running (knots)"] = min_speed_list
    df["max_speed_while_engine_running (knots)"] = max_speed_list
    df = df.dropna(subset=['first_event_time'])

    # Save the final DataFrame.
    df.to_csv("flights_final.csv", sep="\t", index=False, quoting=csv.QUOTE_ALL)
    logging.info("✅ Stage 2 complete: Final CSV with speed columns saved as flights_final.csv")
# Out:
# 2025-04-15 22:26:54,184 - INFO - Starting Stage 1: Processing non-speed columns...
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# 2025-04-15 22:26:59,717 - INFO - Earth Engine initialized successfully in worker.
# 2025-04-15 22:26:59,719 - INFO - Earth Engine initialized successfully in worker.
# 2025-04-15 22:26:59,720 - INFO - Attempting to load IGC file for Flight '25HC48C1': filtered/25HC48C1.IGC
# 2025-04-15 22:26:59,720 - INFO - Attempting to load IGC file for Flight '2020-08-18-CNI-20Y-01': filtered/2020-08-18-CNI-20Y-01.IGC
# 2025-04-15 22:26:59,792 - INFO - File '25HC48C1': IGC file loaded successfully.
# 2025-04-15 22:26:59,796 - INFO - Descent rate calculated: 0.07692307692307693 ft/s
# 2025-04-15 22:26:59,800 - INFO - Distance traveled calculated: 0.11260708510918248 miles
# 2025-04-15 22:26:59,866 - INFO - Earth Engine initialized successfully in worker.
# 2025-04-15 22:26:59,867 - INFO - Attempting to load IGC file for Flight '2018-06-29-NKL-10Q-01': filtered/2018-06-29-NKL-10Q-01.IGC
# 2025-04-15 22:26:59,871 - INFO - File '2020-08-18-CNI-20Y-01': IGC file loaded successfully.
# 2025-04-15 22:26:59,872 - INFO - Earth Engine initialized successfully in worker.
# 2025-04-15 22:26:59,873 - INFO - Attempting to load IGC file for Flight '2021-06-02-CNI-27D-01': filtered/2021-06-02-CNI-27D-01.IGC
# 2025-04-15 22:26:59,875 - INFO - Descent rate calculated: -0.9233333333333333 ft/s
# 2025-04-15 22:26:59,885 - INFO - Earth Engine initialized successfully in worker.
# 2025-04-15 22:26:59,887 - INFO - Attempting to load IGC file for Flight '46PGA9D1': filtered/46PGA9D1.IGC
# 2025-04-15 22:26:59,892 - INFO - Earth Engine initialized successfully in worker.
# 2025-04-15 22:26:59,894 - INFO - Attempting to load IGC file for Flight '2023-06-04-LXV-NBR-01': filtered/2023-06-04-LXV-NBR-01.IGC
# 2025-04-15 22:26:59,895 - INFO - Earth Engine initialized successfully in worker.
# 2025-04-15 22:26:59,897 - INFO - Attempting to load IGC file for Flight '2017-04-17-LXV-2RN-01': filtered/2017-04-17-LXV-2RN-01.IGC
# 2025-04-15 22:26:59,916 - INFO - Distance traveled calculated: 5.467388160734497 miles
# 2025-04-15 22:26:59,960 - INFO - File '2017-04-17-LXV-2RN-01': IGC file loaded successfully.
# 2025-04-15 22:26:59,964 - INFO - File '2021-06-02-CNI-27D-01': IGC file loaded successfully.
# 2025-04-15 22:26:59,965 - INFO - Descent rate calculated: -1.2266666666666666 ft/s
# 2025-04-15 22:26:59,969 - INFO - Descent rate calculated: 0.0 ft/s
# 2025-04-15 22:26:59,974 - INFO - Distance traveled calculated: 0.11451609349044728 miles
# 2025-04-15 22:26:59,979 - INFO - Earth Engine initialized successfully in worker.
# 2025-04-15 22:26:59,980 - INFO - Attempting to load IGC file for Flight '2016-08-07-CNI-255-01': filtered/2016-08-07-CNI-255-01.IGC
# 2025-04-15 22:27:00,001 - INFO - File '2018-06-29-NKL-10Q-01': IGC file loaded successfully.
# 2025-04-15 22:27:00,005 - INFO - Descent rate calculated: -0.7866666666666666 ft/s
# 2025-04-15 22:27:00,005 - INFO - Distance traveled calculated: 5.839055328627815 miles
# 2025-04-15 22:27:00,014 - INFO - Earth Engine initialized successfully in worker.
# 2025-04-15 22:27:00,015 - INFO - Attempting to load IGC file for Flight '2023-08-15-CNI-25N-01': filtered/2023-08-15-CNI-25N-01.IGC
# 2025-04-15 22:27:00,039 - INFO - File '2016-08-07-CNI-255-01': IGC file loaded successfully.
# 2025-04-15 22:27:00,044 - INFO - Descent rate calculated: -1.34 ft/s
# 2025-04-15 22:27:00,046 - INFO - Distance traveled calculated: 5.75225173751222 miles
# 2025-04-15 22:27:00,056 - INFO - Distance traveled calculated: 8.76111577714124 miles
# 2025-04-15 22:27:00,063 - INFO - Earth Engine initialized successfully in worker.
# 2025-04-15 22:27:00,064 - INFO - Attempting to load IGC file for Flight '2018-06-09-CNI-20E-01': filtered/2018-06-09-CNI-20E-01.IGC
# 2025-04-15 22:27:00,079 - INFO - File '46PGA9D1': IGC file loaded successfully.
# 2025-04-15 22:27:00,083 - INFO - Descent rate calculated: -0.7966666666666666 ft/s
# 2025-04-15 22:27:00,089 - INFO - File '2018-06-09-CNI-20E-01': IGC file loaded successfully.
# 2025-04-15 22:27:00,093 - INFO - Descent rate calculated: -0.6933333333333334 ft/s
# 2025-04-15 22:27:00,096 - INFO - File '2023-06-04-LXV-NBR-01': IGC file loaded successfully.
# 2025-04-15 22:27:00,100 - INFO - Descent rate calculated: 1.3233333333333333 ft/s
# 2025-04-15 22:27:00,104 - INFO - Distance traveled calculated: 4.463127839070065 miles
# 2025-04-15 22:27:00,117 - INFO - Earth Engine initialized successfully in worker.
# 2025-04-15 22:27:00,118 - INFO - Attempting to load IGC file for Flight '2023-08-20-CNI-25N-01': filtered/2023-08-20-CNI-25N-01.IGC
# 2025-04-15 22:27:00,126 - INFO - Distance traveled calculated: 7.166435711269646 miles
# 2025-04-15 22:27:00,141 - INFO - Distance traveled calculated: 5.999894172432325 miles
# 2025-04-15 22:27:00,171 - INFO - Earth Engine initialized successfully in worker.
# 2025-04-15 22:27:00,172 - INFO - Attempting to load IGC file for Flight '46RGJUM1': filtered/46RGJUM1.IGC
# 2025-04-15 22:27:00,181 - INFO - File '2023-08-15-CNI-25N-01': IGC file loaded successfully.
# 2025-04-15 22:27:00,185 - INFO - Descent rate calculated: 0.0 ft/s
# 2025-04-15 22:27:00,190 - INFO - Distance traveled calculated: 0.07069837727238815 miles
# 2025-04-15 22:27:00,326 - INFO - File '46RGJUM1': IGC file loaded successfully.
# 2025-04-15 22:27:00,331 - INFO - Descent rate calculated: 0.006289308176100629 ft/s
# 2025-04-15 22:27:00,335 - INFO - Distance traveled calculated: 0.07173190002768376 miles
# 2025-04-15 22:27:00,338 - INFO - File '2023-08-20-CNI-25N-01': IGC file loaded successfully.
# 2025-04-15 22:27:00,341 - INFO - Descent rate calculated: 0.045454545454545456 ft/s
# 2025-04-15 22:27:00,346 - INFO - Attempting to load IGC file for Flight '2021-06-16-CNI-236-01': filtered/2021-06-16-CNI-236-01.IGC
# 2025-04-15 22:27:00,347 - INFO - Distance traveled calculated: 0.07240143845157751 miles
# 2025-04-15 22:27:00,419 - INFO - Descent rate calculated: 0.26666666666666666 ft/s
# 2025-04-15 22:27:00,420 - INFO - Attempting to load IGC file for Flight '2018-08-18-CNI-232-01': filtered/2018-08-18-CNI-232-01.IGC
# 2025-04-15 22:27:00,430 - INFO - Distance traveled calculated: 5.358018263441912 miles
# 2025-04-15 22:27:00,478 - INFO - File '2018-08-18-CNI-232-01': IGC file loaded successfully.
# 2025-04-15 22:27:00,480 - INFO - Descent rate calculated: 1.9233333333333333 ft/s
# 2025-04-15 22:27:00,491 - INFO - Distance traveled calculated: 5.632194366105081 miles
# 2025-04-15 22:27:00,497 - INFO - File '2021-06-16-CNI-236-01': IGC file loaded successfully.
# 2025-04-15 22:27:00,499 - INFO - Descent rate calculated: 0.043478260869565216 ft/s
# 2025-04-15 22:27:00,504 - INFO - Distance traveled calculated: 0.09266201714956414 miles
# 2025-04-15 22:27:00,531 - INFO - Attempting to load IGC file for Flight '2018-08-19-CNI-27D-01': filtered/2018-08-19-CNI-27D-01.IGC
# 2025-04-15 22:27:00,547 - INFO - Attempting to load IGC file for Flight '2016-08-10-CNI-22M-01': filtered/2016-08-10-CNI-22M-01.IGC
# 2025-04-15 22:27:00,586 - INFO - File '2018-08-19-CNI-27D-01': IGC file loaded successfully.
# 2025-04-15 22:27:00,588 - INFO - Descent rate calculated: -0.06451612903225806 ft/s
# 2025-04-15 22:27:00,592 - INFO - Distance traveled calculated: 0.10093920250572952 miles
# 2025-04-15 22:27:00,613 - INFO - Attempting to load IGC file for Flight '34PLCS74': filtered/34PLCS74.IGC
# 2025-04-15 22:27:00,618 - INFO - File '2016-08-10-CNI-22M-01': IGC file loaded successfully.
# 2025-04-15 22:27:00,620 - INFO - Descent rate calculated: 0.03225806451612903 ft/s
# 2025-04-15 22:27:00,624 - INFO - Distance traveled calculated: 0.10549389473348787 miles
# 2025-04-15 22:27:00,643 - INFO - Attempting to load IGC file for Flight '2023-06-26-LXV-7EO-01': filtered/2023-06-26-LXV-7EO-01.IGC
# 2025-04-15 22:27:00,649 - INFO - File '34PLCS74': IGC file loaded successfully.
# 2025-04-15 22:27:00,651 - INFO - Descent rate calculated: -0.02027027027027027 ft/s
# 2025-04-15 22:27:00,660 - INFO - Distance traveled calculated: 4.2845908396327825 miles
# 2025-04-15 22:27:00,676 - INFO - Attempting to load IGC file for Flight '03EGIQO1': filtered/03EGIQO1.IGC
# 2025-04-15 22:27:00,700 - INFO - Attempting to load IGC file for Flight '2024-08-04-CNI-29F-01': filtered/2024-08-04-CNI-29F-01.IGC
# 2025-04-15 22:27:00,730 - INFO - Attempting to load IGC file for Flight '2014-05-22-NKL-10R-01': filtered/2014-05-22-NKL-10R-01.IGC
# 2025-04-15 22:27:00,735 - INFO - Attempting to load IGC file for Flight '23IGA9D1': filtered/23IGA9D1.IGC
# 2025-04-15 22:27:00,759 - INFO - File '2024-08-04-CNI-29F-01': IGC file loaded successfully.
# 2025-04-15 22:27:00,761 - INFO - Descent rate calculated: 0.07 ft/s
# 2025-04-15 22:27:00,774 - INFO - Distance traveled calculated: 5.4686949740998925 miles
# 2025-04-15 22:27:00,783 - INFO - File '2023-06-26-LXV-7EO-01': IGC file loaded successfully.
# 2025-04-15 22:27:00,784 - INFO - Descent rate calculated: 0.0 ft/s
# 2025-04-15 22:27:00,796 - INFO - File '2014-05-22-NKL-10R-01': IGC file loaded successfully.
# 2025-04-15 22:27:00,798 - INFO - Descent rate calculated: -0.47333333333333333 ft/s
# 2025-04-15 22:27:00,804 - INFO - Distance traveled calculated: 0.10862154187314865 miles
# 2025-04-15 22:27:00,809 - INFO - Distance traveled calculated: 6.141103828340458 miles
# 2025-04-15 22:27:00,838 - INFO - Descent rate calculated: -0.8566666666666667 ft/s
# 2025-04-15 22:27:00,841 - INFO - File '03EGIQO1': IGC file loaded successfully.
# 2025-04-15 22:27:00,843 - INFO - Descent rate calculated: -0.8933333333333333 ft/s
# 2025-04-15 22:27:00,849 - INFO - Distance traveled calculated: 7.334802001353826 miles
# 2025-04-15 22:27:00,881 - INFO - Distance traveled calculated: 5.558330022169933 miles
# 2025-04-15 22:27:00,891 - INFO - File '23IGA9D1': IGC file loaded successfully.
# 2025-04-15 22:27:00,893 - INFO - Descent rate calculated: -2.0966666666666667 ft/s
# 2025-04-15 22:27:00,931 - INFO - Distance traveled calculated: 9.141313472916792 miles
# 2025-04-15 22:27:00,972 - INFO - Attempting to load IGC file for Flight '2013-04-25-NKL-10Q-01': filtered/2013-04-25-NKL-10Q-01.IGC
# 2025-04-15 22:27:00,981 - INFO - Attempting to load IGC file for Flight '2021-06-19-LXV-780-01': filtered/2021-06-19-LXV-780-01.IGC
# 2025-04-15 22:27:00,996 - INFO - File '2013-04-25-NKL-10Q-01': IGC file loaded successfully.
# 2025-04-15 22:27:00,997 - INFO - Attempting to load IGC file for Flight '2018-06-20-CNI-27D-01': filtered/2018-06-20-CNI-27D-01.IGC
# 2025-04-15 22:27:00,998 - INFO - Descent rate calculated: 1.69 ft/s
# 2025-04-15 22:27:01,013 - INFO - Distance traveled calculated: 4.866050510927638 miles
# 2025-04-15 22:27:01,021 - INFO - Attempting to load IGC file for Flight '2016-05-26-CNI-21L-01': filtered/2016-05-26-CNI-21L-01.IGC
# 2025-04-15 22:27:01,022 - INFO - Attempting to load IGC file for Flight '2018-03-14-CNI-20E-01': filtered/2018-03-14-CNI-20E-01.IGC
# 2025-04-15 22:27:01,024 - INFO - Attempting to load IGC file for Flight '2017-03-15-CNI-22G-01': filtered/2017-03-15-CNI-22G-01.IGC
# 2025-04-15 22:27:01,028 - INFO - Attempting to load IGC file for Flight '2021-06-02-FLA-JEU-01': filtered/2021-06-02-FLA-JEU-01.IGC
# 2025-04-15 22:27:01,041 - INFO - File '2016-05-26-CNI-21L-01': IGC file loaded successfully.
# 2025-04-15 22:27:01,043 - INFO - Descent rate calculated: -1.0266666666666666 ft/s
# 2025-04-15 22:27:01,053 - INFO - Distance traveled calculated: 5.733426457340437 miles
# 2025-04-15 22:27:01,054 - INFO - File '2017-03-15-CNI-22G-01': IGC file loaded successfully.
# 2025-04-15 22:27:01,056 - INFO - Descent rate calculated: 1.1372549019607843 ft/s
# 2025-04-15 22:27:01,058 - INFO - File '2021-06-19-LXV-780-01': IGC file loaded successfully.
# 2025-04-15 22:27:01,060 - INFO - File '2018-03-14-CNI-20E-01': IGC file loaded successfully.
# 2025-04-15 22:27:01,060 - INFO - Descent rate calculated: 0.016216216216216217 ft/s
# 2025-04-15 22:27:01,061 - INFO - Descent rate calculated: -0.84 ft/s
# 2025-04-15 22:27:01,063 - INFO - Distance traveled calculated: 1.5444810894126404 miles
# 2025-04-15 22:27:01,065 - INFO - File '2018-06-20-CNI-27D-01': IGC file loaded successfully.
# 2025-04-15 22:27:01,066 - INFO - Descent rate calculated: 0.1111111111111111 ft/s
# 2025-04-15 22:27:01,070 - INFO - Distance traveled calculated: 0.0621552775468063 miles
# 2025-04-15 22:27:01,072 - INFO - Distance traveled calculated: 4.673325732646688 miles
# 2025-04-15 22:27:01,074 - INFO - Attempting to load IGC file for Flight '2019-06-05-CNI-27K-01': filtered/2019-06-05-CNI-27K-01.IGC
# 2025-04-15 22:27:01,081 - INFO - Distance traveled calculated: 0.15606857560047532 miles
# 2025-04-15 22:27:01,107 - INFO - File '2019-06-05-CNI-27K-01': IGC file loaded successfully.
# 2025-04-15 22:27:01,108 - INFO - Descent rate calculated: -1.0333333333333334 ft/s
# 2025-04-15 22:27:01,119 - INFO - Distance traveled calculated: 5.2554034481284 miles
# 2025-04-15 22:27:01,130 - INFO - Attempting to load IGC file for Flight '2017-06-09-CNI-22G-01': filtered/2017-06-09-CNI-22G-01.IGC
# 2025-04-15 22:27:01,141 - INFO - Attempting to load IGC file for Flight '06CC4A41': filtered/06CC4A41.IGC
# 2025-04-15 22:27:01,179 - INFO - File '2017-06-09-CNI-22G-01': IGC file loaded successfully.
# 2025-04-15 22:27:01,180 - INFO - Descent rate calculated: -0.05128205128205128 ft/s
# 2025-04-15 22:27:01,183 - INFO - File '06CC4A41': IGC file loaded successfully.
# 2025-04-15 22:27:01,184 - INFO - Descent rate calculated: 2.4597701149425286 ft/s
# 2025-04-15 22:27:01,185 - INFO - Distance traveled calculated: 0.2247874735611018 miles
# 2025-04-15 22:27:01,194 - INFO - Distance traveled calculated: 4.778870092609645 miles
# 2025-04-15 22:27:01,243 - INFO - Attempting to load IGC file for Flight '2016-05-24-NKL-0UM-01': filtered/2016-05-24-NKL-0UM-01.IGC
# 2025-04-15 22:27:01,278 - INFO - Attempting to load IGC file for Flight '2021-08-04-CNI-23Y-01': filtered/2021-08-04-CNI-23Y-01.IGC
# 2025-04-15 22:27:01,284 - INFO - File '2021-06-02-FLA-JEU-01': IGC file loaded successfully.
# 2025-04-15 22:27:01,286 - INFO - Descent rate calculated: 0.05172413793103448 ft/s
# 2025-04-15 22:27:01,289 - INFO - Distance traveled calculated: 0.18036718831070772 miles
# 2025-04-15 22:27:01,292 - INFO - Attempting to load IGC file for Flight '2021-06-20-LXV-780-01': filtered/2021-06-20-LXV-780-01.IGC
# 2025-04-15 22:27:01,297 - INFO - Attempting to load IGC file for Flight '2018-08-09-CNI-232-01': filtered/2018-08-09-CNI-232-01.IGC
# 2025-04-15 22:27:01,299 - INFO - Attempting to load IGC file for Flight '2017-06-27-CNI-23P-01': filtered/2017-06-27-CNI-23P-01.IGC
# 2025-04-15 22:27:01,326 - INFO - File '2021-08-04-CNI-23Y-01': IGC file loaded successfully.
# 2025-04-15 22:27:01,328 - INFO - Descent rate calculated: 0.0 ft/s
# 2025-04-15 22:27:01,332 - INFO - Distance traveled calculated: 0.10155166328780722 miles
# 2025-04-15 22:27:01,336 - INFO - File '2016-05-24-NKL-0UM-01': IGC file loaded successfully.
# 2025-04-15 22:27:01,338 - INFO - Descent rate calculated: 0.022727272727272728 ft/s
# 2025-04-15 22:27:01,344 - INFO - File '2018-08-09-CNI-232-01': IGC file loaded successfully.
# 2025-04-15 22:27:01,344 - INFO - File '2017-06-27-CNI-23P-01': IGC file loaded successfully.
# 2025-04-15 22:27:01,346 - INFO - Descent rate calculated: 0.0 ft/s
# 2025-04-15 22:27:01,346 - INFO - Descent rate calculated: -0.13 ft/s
# 2025-04-15 22:27:01,350 - INFO - Distance traveled calculated: 0.09991176568555214 miles
# 2025-04-15 22:27:01,353 - INFO - Distance traveled calculated: 0.11381513863935487 miles
# 2025-04-15 22:27:01,355 - INFO - Attempting to load IGC file for Flight '2019-06-20-CNI-27D-01': filtered/2019-06-20-CNI-27D-01.IGC
# 2025-04-15 22:27:01,356 - INFO - Distance traveled calculated: 5.175687409566518 miles
# 2025-04-15 22:27:01,358 - INFO - Descent rate calculated: 0.25333333333333335 ft/s
# 2025-04-15 22:27:01,364 - INFO - File '2021-06-20-LXV-780-01': IGC file loaded successfully.
# 2025-04-15 22:27:01,366 - INFO - Descent rate calculated: 0.011428571428571429 ft/s
# 2025-04-15 22:27:01,369 - INFO - Distance traveled calculated: 6.969639438052497 miles
# 2025-04-15 22:27:01,386 - INFO - Distance traveled calculated: 0.12400931431735754 miles
# 2025-04-15 22:27:01,387 - INFO - Attempting to load IGC file for Flight '2019-06-23-CNI-27D-01': filtered/2019-06-23-CNI-27D-01.IGC
# 2025-04-15 22:27:01,418 - INFO - File '2019-06-20-CNI-27D-01': IGC file loaded successfully.
# 2025-04-15 22:27:01,420 - INFO - Descent rate calculated: 0.0 ft/s
# 2025-04-15 22:27:01,424 - INFO - Distance traveled calculated: 0.10109149933242821 miles
# 2025-04-15 22:27:01,428 - INFO - Attempting to load IGC file for Flight '2015-10-12-CNI-20Y-01': filtered/2015-10-12-CNI-20Y-01.IGC
# 2025-04-15 22:27:01,448 - INFO - File '2019-06-23-CNI-27D-01': IGC file loaded successfully.
# 2025-04-15 22:27:01,449 - INFO - Attempting to load IGC file for Flight '46MG8KM1': filtered/46MG8KM1.IGC
# 2025-04-15 22:27:01,449 - INFO - File '2015-10-12-CNI-20Y-01': IGC file loaded successfully.
# 2025-04-15 22:27:01,450 - INFO - Descent rate calculated: 0.041666666666666664 ft/s
# 2025-04-15 22:27:01,451 - INFO - Descent rate calculated: -0.8933333333333333 ft/s
# 2025-04-15 22:27:01,454 - INFO - Distance traveled calculated: 0.09155806897988356 miles
# 2025-04-15 22:27:01,462 - INFO - Distance traveled calculated: 4.613394484287259 miles
# 2025-04-15 22:27:01,501 - INFO - Descent rate calculated: -1.01 ft/s
# 2025-04-15 22:27:01,511 - INFO - Attempting to load IGC file for Flight '2021-04-18-CNI-21D-01': filtered/2021-04-18-CNI-21D-01.IGC
# 2025-04-15 22:27:01,512 - INFO - Distance traveled calculated: 6.36001158991502 miles
# 2025-04-15 22:27:01,539 - INFO - File '2021-04-18-CNI-21D-01': IGC file loaded successfully.
# 2025-04-15 22:27:01,541 - INFO - Descent rate calculated: -0.2777777777777778 ft/s
# 2025-04-15 22:27:01,545 - INFO - Distance traveled calculated: 0.06512913898043138 miles
# 2025-04-15 22:27:01,554 - INFO - Attempting to load IGC file for Flight '2021-07-20-LXV-780-01': filtered/2021-07-20-LXV-780-01.IGC
# 2025-04-15 22:27:01,560 - INFO - Attempting to load IGC file for Flight '561LCS71': filtered/561LCS71.IGC
# 2025-04-15 22:27:01,582 - INFO - File '561LCS71': IGC file loaded successfully.
# 2025-04-15 22:27:01,584 - INFO - Descent rate calculated: -0.996551724137931 ft/s
# 2025-04-15 22:27:01,588 - INFO - Distance traveled calculated: 4.91999358482518 miles
# 2025-04-15 22:27:01,591 - INFO - Attempting to load IGC file for Flight '2024-06-17-CNI-27Z-01': filtered/2024-06-17-CNI-27Z-01.IGC
# 2025-04-15 22:27:01,625 - INFO - File '46MG8KM1': IGC file loaded successfully.
# 2025-04-15 22:27:01,627 - INFO - Descent rate calculated: 0.032467532467532464 ft/s
# 2025-04-15 22:27:01,630 - INFO - Distance traveled calculated: 0.06862760064450973 miles
# 2025-04-15 22:27:01,654 - INFO - Attempting to load IGC file for Flight '2020-03-13-CNI-27G-01': filtered/2020-03-13-CNI-27G-01.IGC
# 2025-04-15 22:27:01,672 - INFO - Attempting to load IGC file for Flight '2021-06-04-CNI-27D-01': filtered/2021-06-04-CNI-27D-01.IGC
# 2025-04-15 22:27:01,676 - INFO - File '2021-07-20-LXV-780-01': IGC file loaded successfully.
# 2025-04-15 22:27:01,678 - INFO - Descent rate calculated: 0.00558659217877095 ft/s
# 2025-04-15 22:27:01,678 - INFO - Attempting to load IGC file for Flight '14HG8KM1': filtered/14HG8KM1.IGC
# 2025-04-15 22:27:01,696 - INFO - Attempting to load IGC file for Flight '2017-08-10-CNI-20Y-01': filtered/2017-08-10-CNI-20Y-01.IGC
# 2025-04-15 22:27:01,699 - INFO - Distance traveled calculated: 0.13990715653635524 miles
# 2025-04-15 22:27:01,699 - INFO - File '2020-03-13-CNI-27G-01': IGC file loaded successfully.
# 2025-04-15 22:27:01,701 - INFO - Descent rate calculated: 0.43 ft/s
# 2025-04-15 22:27:01,711 - INFO - Distance traveled calculated: 6.060112561736622 miles
# 2025-04-15 22:27:01,731 - INFO - File '2024-06-17-CNI-27Z-01': IGC file loaded successfully.
# 2025-04-15 22:27:01,733 - INFO - Descent rate calculated: -2.8933333333333335 ft/s
# 2025-04-15 22:27:01,735 - INFO - File '14HG8KM1': IGC file loaded successfully.
# 2025-04-15 22:27:01,737 - INFO - Descent rate calculated: 0.012987012987012988 ft/s
# 2025-04-15 22:27:01,740 - INFO - File '2021-06-04-CNI-27D-01': IGC file loaded successfully.
# 2025-04-15 22:27:01,740 - INFO - Distance traveled calculated: 0.06042911804323401 miles
# 2025-04-15 22:27:01,741 - INFO - Descent rate calculated: 0.4166666666666667 ft/s
# 2025-04-15 22:27:01,747 - INFO - Distance traveled calculated: 0.4836421114254943 miles
# 2025-04-15 22:27:01,753 - INFO - File '2017-08-10-CNI-20Y-01': IGC file loaded successfully.
# 2025-04-15 22:27:01,754 - INFO - Descent rate calculated: -0.77 ft/s
# 2025-04-15 22:27:01,754 - INFO - Descent rate calculated: -1.6233333333333333 ft/s
# 2025-04-15 22:27:01,765 - INFO - Distance traveled calculated: 7.857563060582664 miles
# 2025-04-15 22:27:01,765 - INFO - Distance traveled calculated: 5.979364622755721 miles
# 2025-04-15 22:27:01,774 - INFO - Distance traveled calculated: 6.227537354353812 miles
# 2025-04-15 22:27:01,792 - INFO - Attempting to load IGC file for Flight '2019-04-24-CNI-22A-01': filtered/2019-04-24-CNI-22A-01.IGC
# 2025-04-15 22:27:01,885 - INFO - Descent rate calculated: -0.9133333333333333 ft/s
# 2025-04-15 22:27:01,894 - INFO - Descent rate calculated: -0.9566666666666667 ft/s
# 2025-04-15 22:27:01,896 - INFO - Distance traveled calculated: 5.886622733747102 miles
# 2025-04-15 22:27:01,905 - INFO - Distance traveled calculated: 5.563605136403988 miles
# 2025-04-15 22:27:01,926 - INFO - Attempting to load IGC file for Flight '2019-08-21-CNI-23Y-01': filtered/2019-08-21-CNI-23Y-01.IGC
# 2025-04-15 22:27:01,965 - INFO - File '2019-08-21-CNI-23Y-01': IGC file loaded successfully.
# 2025-04-15 22:27:01,966 - INFO - Descent rate calculated: 0.037037037037037035 ft/s
# 2025-04-15 22:27:01,970 - INFO - Distance traveled calculated: 0.061304319930079676 miles
# 2025-04-15 22:27:01,970 - INFO - Attempting to load IGC file for Flight '2021-03-15-LXV-AGO-02': filtered/2021-03-15-LXV-AGO-02.IGC
# 2025-04-15 22:27:01,977 - INFO - Attempting to load IGC file for Flight '2021-06-28-CNI-27Z-01': filtered/2021-06-28-CNI-27Z-01.IGC
# 2025-04-15 22:27:01,981 - INFO - Attempting to load IGC file for Flight '03FGIQO1': filtered/03FGIQO1.IGC
# 2025-04-15 22:27:02,002 - INFO - File '2019-04-24-CNI-22A-01': IGC file loaded successfully.
# 2025-04-15 22:27:02,004 - INFO - Descent rate calculated: -0.5833333333333334 ft/s
# 2025-04-15 22:27:02,032 - INFO - Attempting to load IGC file for Flight '2018-07-01-LXV-3IL-01': filtered/2018-07-01-LXV-3IL-01.IGC
# 2025-04-15 22:27:02,044 - INFO - Distance traveled calculated: 4.742354574229855 miles
# 2025-04-15 22:27:02,046 - INFO - Attempting to load IGC file for Flight '2019-07-16-CNI-20Y-01': filtered/2019-07-16-CNI-20Y-01.IGC
# 2025-04-15 22:27:02,046 - INFO - Attempting to load IGC file for Flight '2017-09-23-CNI-20Y-01': filtered/2017-09-23-CNI-20Y-01.IGC
# 2025-04-15 22:27:02,070 - INFO - Descent rate calculated: -0.3433333333333333 ft/s
# 2025-04-15 22:27:02,070 - INFO - File '2017-09-23-CNI-20Y-01': IGC file loaded successfully.
# 2025-04-15 22:27:02,072 - INFO - Descent rate calculated: -1.4366666666666668 ft/s
# 2025-04-15 22:27:02,080 - INFO - Distance traveled calculated: 6.934508020873657 miles
# 2025-04-15 22:27:02,082 - INFO - Distance traveled calculated: 7.301592884315906 miles
# 2025-04-15 22:27:02,111 - INFO - File '2019-07-16-CNI-20Y-01': IGC file loaded successfully.
# 2025-04-15 22:27:02,113 - INFO - Descent rate calculated: -0.91 ft/s
# 2025-04-15 22:27:02,138 - INFO - File '03FGIQO1': IGC file loaded successfully.
# 2025-04-15 22:27:02,139 - INFO - Descent rate calculated: 0.35333333333333333 ft/s
# 2025-04-15 22:27:02,142 - INFO - Attempting to load IGC file for Flight '46NG8KM1': filtered/46NG8KM1.IGC
# 2025-04-15 22:27:02,148 - INFO - File '2021-06-28-CNI-27Z-01': IGC file loaded successfully.
# 2025-04-15 22:27:02,150 - INFO - Descent rate calculated: -0.6333333333333333 ft/s
# 2025-04-15 22:27:02,153 - INFO - Distance traveled calculated: 5.688222628455125 miles
# 2025-04-15 22:27:02,163 - INFO - Attempting to load IGC file for Flight '2021-06-29-CNI-27D-01': filtered/2021-06-29-CNI-27D-01.IGC
# 2025-04-15 22:27:02,163 - INFO - File '2021-03-15-LXV-AGO-02': IGC file loaded successfully.
# 2025-04-15 22:27:02,165 - INFO - Descent rate calculated: -0.014634146341463415 ft/s
# 2025-04-15 22:27:02,179 - INFO - Distance traveled calculated: 6.0239732363025835 miles
# 2025-04-15 22:27:02,188 - INFO - Distance traveled calculated: 0.070906495989514 miles
# 2025-04-15 22:27:02,189 - INFO - Distance traveled calculated: 9.533174580697606 miles
# 2025-04-15 22:27:02,214 - INFO - File '2018-07-01-LXV-3IL-01': IGC file loaded successfully.
# 2025-04-15 22:27:02,216 - INFO - Descent rate calculated: 0.23809523809523808 ft/s
# 2025-04-15 22:27:02,219 - INFO - Distance traveled calculated: 5345.928712957068 miles
# 2025-04-15 22:27:02,232 - INFO - File '2021-06-29-CNI-27D-01': IGC file loaded successfully.
# 2025-04-15 22:27:02,234 - INFO - Descent rate calculated: 1.7233333333333334 ft/s
# 2025-04-15 22:27:02,250 - INFO - Distance traveled calculated: 6.20363133863378 miles
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:    8.0s
# 2025-04-15 22:27:02,284 - INFO - Attempting to load IGC file for Flight '2024-04-26-LXV-NBR-01': filtered/2024-04-26-LXV-NBR-01.IGC
# 2025-04-15 22:27:02,284 - INFO - Attempting to load IGC file for Flight '2018-07-05-LXV-3IL-01': filtered/2018-07-05-LXV-3IL-01.IGC
# 2025-04-15 22:27:02,290 - INFO - Descent rate calculated: 0.3466666666666667 ft/s
# 2025-04-15 22:27:02,292 - INFO - Attempting to load IGC file for Flight '2022-07-17-CNI-20Y-01': filtered/2022-07-17-CNI-20Y-01.IGC
# 2025-04-15 22:27:02,301 - INFO - Distance traveled calculated: 6.250655807490728 miles
# 2025-04-15 22:27:02,334 - INFO - File '2022-07-17-CNI-20Y-01': IGC file loaded successfully.
# 2025-04-15 22:27:02,336 - INFO - File '2024-04-26-LXV-NBR-01': IGC file loaded successfully.
# 2025-04-15 22:27:02,336 - INFO - Descent rate calculated: -0.8766666666666667 ft/s
# 2025-04-15 22:27:02,338 - INFO - Descent rate calculated: -0.9 ft/s
# 2025-04-15 22:27:02,342 - INFO - Attempting to load IGC file for Flight '2019-05-07-CNI-27G-01': filtered/2019-05-07-CNI-27G-01.IGC
# 2025-04-15 22:27:02,347 - INFO - Distance traveled calculated: 5.853348470145102 miles
# 2025-04-15 22:27:02,364 - INFO - Attempting to load IGC file for Flight '2017-04-17-LXV-JD2-01': filtered/2017-04-17-LXV-JD2-01.IGC
# 2025-04-15 22:27:02,373 - INFO - File '46NG8KM1': IGC file loaded successfully.
# 2025-04-15 22:27:02,375 - INFO - Descent rate calculated: 0.025 ft/s
# 2025-04-15 22:27:02,376 - INFO - Distance traveled calculated: 6.695436746519116 miles
# 2025-04-15 22:27:02,378 - INFO - Distance traveled calculated: 0.0819394148619763 miles
# 2025-04-15 22:27:02,385 - INFO - File '2019-05-07-CNI-27G-01': IGC file loaded successfully.
# 2025-04-15 22:27:02,387 - INFO - Descent rate calculated: 0.04666666666666667 ft/s
# 2025-04-15 22:27:02,397 - INFO - Distance traveled calculated: 5.800562819825265 miles
# 2025-04-15 22:27:02,418 - INFO - File '2017-04-17-LXV-JD2-01': IGC file loaded successfully.
# 2025-04-15 22:27:02,420 - INFO - Descent rate calculated: -0.14285714285714285 ft/s
# 2025-04-15 22:27:02,423 - INFO - Distance traveled calculated: 0.06573704681555634 miles
# 2025-04-15 22:27:02,443 - INFO - File '2018-07-05-LXV-3IL-01': IGC file loaded successfully.
# 2025-04-15 22:27:02,445 - INFO - Descent rate calculated: 0.13043478260869565 ft/s
# 2025-04-15 22:27:02,449 - INFO - Distance traveled calculated: 0.05791497954097598 miles
# 2025-04-15 22:27:02,475 - INFO - Attempting to load IGC file for Flight '2021-06-05-FLA-JUM-01': filtered/2021-06-05-FLA-JUM-01.IGC
# 2025-04-15 22:27:02,549 - INFO - Attempting to load IGC file for Flight '2015-03-17-NKL-0VP-01': filtered/2015-03-17-NKL-0VP-01.IGC
# 2025-04-15 22:27:02,554 - INFO - Attempting to load IGC file for Flight '2013-06-24-NKL-0T9-01': filtered/2013-06-24-NKL-0T9-01.IGC
# 2025-04-15 22:27:02,573 - INFO - File '2015-03-17-NKL-0VP-01': IGC file loaded successfully.
# 2025-04-15 22:27:02,574 - INFO - Descent rate calculated: 0.21875 ft/s
# 2025-04-15 22:27:02,578 - INFO - Distance traveled calculated: 0.20956139823716272 miles
# 2025-04-15 22:27:02,609 - INFO - Attempting to load IGC file for Flight '2016-04-18-CNI-21L-01': filtered/2016-04-18-CNI-21L-01.IGC
# 2025-04-15 22:27:02,611 - INFO - File '2013-06-24-NKL-0T9-01': IGC file loaded successfully.
# 2025-04-15 22:27:02,612 - INFO - File '2021-06-05-FLA-JUM-01': IGC file loaded successfully.
# 2025-04-15 22:27:02,613 - INFO - Descent rate calculated: -0.18666666666666668 ft/s
# 2025-04-15 22:27:02,614 - INFO - Descent rate calculated: -1.0833333333333333 ft/s
# 2025-04-15 22:27:02,614 - INFO - Attempting to load IGC file for Flight '2024-06-07-CNI-24W-01': filtered/2024-06-07-CNI-24W-01.IGC
# 2025-04-15 22:27:02,621 - INFO - Attempting to load IGC file for Flight '2019-07-19-CNI-20Y-01': filtered/2019-07-19-CNI-20Y-01.IGC
# 2025-04-15 22:27:02,624 - INFO - Distance traveled calculated: 7.083252307285193 miles
# 2025-04-15 22:27:02,629 - INFO - Attempting to load IGC file for Flight '2021-06-14-FLA-8DI-01': filtered/2021-06-14-FLA-8DI-01.IGC
# 2025-04-15 22:27:02,637 - INFO - File '2016-04-18-CNI-21L-01': IGC file loaded successfully.
# 2025-04-15 22:27:02,638 - INFO - Descent rate calculated: -0.37 ft/s
# 2025-04-15 22:27:02,649 - INFO - Distance traveled calculated: 5.119571087528898 miles
# 2025-04-15 22:27:02,651 - INFO - Attempting to load IGC file for Flight '2011-08-06-NKL-0Z0-01': filtered/2011-08-06-NKL-0Z0-01.IGC
# 2025-04-15 22:27:02,655 - INFO - Distance traveled calculated: 8.47557842710479 miles
# 2025-04-15 22:27:02,682 - INFO - File '2019-07-19-CNI-20Y-01': IGC file loaded successfully.
# 2025-04-15 22:27:02,684 - INFO - Descent rate calculated: -1.0666666666666667 ft/s
# 2025-04-15 22:27:02,696 - INFO - File '2011-08-06-NKL-0Z0-01': IGC file loaded successfully.
# 2025-04-15 22:27:02,698 - INFO - File '2021-06-14-FLA-8DI-01': IGC file loaded successfully.
# 2025-04-15 22:27:02,698 - INFO - Descent rate calculated: 2.033333333333333 ft/s
# 2025-04-15 22:27:02,700 - INFO - Descent rate calculated: -0.012269938650306749 ft/s
# 2025-04-15 22:27:02,704 - INFO - Distance traveled calculated: 0.12784240101929473 miles
# 2025-04-15 22:27:02,714 - INFO - Distance traveled calculated: 4.793387907484087 miles
# 2025-04-15 22:27:02,724 - INFO - Distance traveled calculated: 6.077329577952427 miles
# 2025-04-15 22:27:02,765 - INFO - Descent rate calculated: -0.7 ft/s
# 2025-04-15 22:27:02,766 - INFO - Attempting to load IGC file for Flight '2017-08-03-CNI-20E-01': filtered/2017-08-03-CNI-20E-01.IGC
# 2025-04-15 22:27:02,775 - INFO - Distance traveled calculated: 6.998181327501781 miles
# 2025-04-15 22:27:02,781 - INFO - Attempting to load IGC file for Flight '36FLCLO1': filtered/36FLCLO1.IGC
# 2025-04-15 22:27:02,808 - INFO - File '2024-06-07-CNI-24W-01': IGC file loaded successfully.
# 2025-04-15 22:27:02,810 - INFO - Descent rate calculated: 0.03333333333333333 ft/s
# 2025-04-15 22:27:02,811 - INFO - File '36FLCLO1': IGC file loaded successfully.
# 2025-04-15 22:27:02,813 - INFO - Descent rate calculated: 0.05813953488372093 ft/s
# 2025-04-15 22:27:02,814 - INFO - Distance traveled calculated: 0.08805015969084325 miles
# 2025-04-15 22:27:02,815 - INFO - Distance traveled calculated: 0.23945442287326668 miles
# 2025-04-15 22:27:02,819 - INFO - File '2017-08-03-CNI-20E-01': IGC file loaded successfully.
# 2025-04-15 22:27:02,821 - INFO - Descent rate calculated: -0.7833333333333333 ft/s
# 2025-04-15 22:27:02,831 - INFO - Distance traveled calculated: 5.510110495977391 miles
# 2025-04-15 22:27:02,883 - INFO - Attempting to load IGC file for Flight '2016-03-16-CNI-22G-01': filtered/2016-03-16-CNI-22G-01.IGC
# 2025-04-15 22:27:02,886 - INFO - Descent rate calculated: 0.9133333333333333 ft/s
# 2025-04-15 22:27:02,897 - INFO - Distance traveled calculated: 5.8795264676853 miles
# 2025-04-15 22:27:02,913 - INFO - Attempting to load IGC file for Flight '2019-04-24-CNI-27G-01': filtered/2019-04-24-CNI-27G-01.IGC
# 2025-04-15 22:27:02,940 - INFO - Attempting to load IGC file for Flight '04NC4A41': filtered/04NC4A41.IGC
# 2025-04-15 22:27:02,949 - INFO - File '2016-03-16-CNI-22G-01': IGC file loaded successfully.
# 2025-04-15 22:27:02,950 - INFO - Descent rate calculated: -0.03333333333333333 ft/s
# 2025-04-15 22:27:02,954 - INFO - Attempting to load IGC file for Flight '2021-05-31-CNI-27D-01': filtered/2021-05-31-CNI-27D-01.IGC
# 2025-04-15 22:27:02,955 - INFO - Distance traveled calculated: 0.12387706627860984 miles
# 2025-04-15 22:27:02,969 - INFO - Descent rate calculated: 0.056666666666666664 ft/s
# 2025-04-15 22:27:02,980 - INFO - Distance traveled calculated: 7.52661847397513 miles
# 2025-04-15 22:27:02,983 - INFO - File '2019-04-24-CNI-27G-01': IGC file loaded successfully.
# 2025-04-15 22:27:02,985 - INFO - Descent rate calculated: 0.7066666666666667 ft/s
# 2025-04-15 22:27:02,986 - INFO - Descent rate calculated: -0.99 ft/s
# 2025-04-15 22:27:02,987 - INFO - File '04NC4A41': IGC file loaded successfully.
# 2025-04-15 22:27:02,992 - INFO - Descent rate calculated: 2.3136531365313653 ft/s
# 2025-04-15 22:27:02,995 - INFO - Descent rate calculated: -0.61 ft/s
# 2025-04-15 22:27:02,996 - INFO - Distance traveled calculated: 4.321970191931229 miles
# 2025-04-15 22:27:02,997 - INFO - Distance traveled calculated: 7.2528119212928175 miles
# 2025-04-15 22:27:03,004 - INFO - Distance traveled calculated: 5.866190882145827 miles
# 2025-04-15 22:27:03,006 - INFO - Distance traveled calculated: 7.218454949208769 miles
# 2025-04-15 22:27:03,035 - INFO - File '2021-05-31-CNI-27D-01': IGC file loaded successfully.
# 2025-04-15 22:27:03,037 - INFO - Descent rate calculated: 0.0 ft/s
# 2025-04-15 22:27:03,042 - INFO - Distance traveled calculated: 0.13105399017007047 miles
# 2025-04-15 22:27:03,053 - INFO - Attempting to load IGC file for Flight '2018-03-11-CNI-20E-01': filtered/2018-03-11-CNI-20E-01.IGC
# 2025-04-15 22:27:03,074 - INFO - Attempting to load IGC file for Flight '339LCLO1': filtered/339LCLO1.IGC
# 2025-04-15 22:27:03,090 - INFO - File '339LCLO1': IGC file loaded successfully.
# 2025-04-15 22:27:03,092 - INFO - Descent rate calculated: 0.26013513513513514 ft/s
# 2025-04-15 22:27:03,096 - INFO - Distance traveled calculated: 0.45670711635549843 miles
# 2025-04-15 22:27:03,106 - INFO - File '2018-03-11-CNI-20E-01': IGC file loaded successfully.
# 2025-04-15 22:27:03,108 - INFO - Descent rate calculated: -0.7633333333333333 ft/s
# 2025-04-15 22:27:03,118 - INFO - Distance traveled calculated: 5.072267741344613 miles
# 2025-04-15 22:27:03,164 - INFO - Attempting to load IGC file for Flight '2018-07-04-LXV-3IL-01': filtered/2018-07-04-LXV-3IL-01.IGC
# 2025-04-15 22:27:03,174 - INFO - Descent rate calculated: -0.21 ft/s
# 2025-04-15 22:27:03,179 - INFO - Attempting to load IGC file for Flight '2019-09-15-CNI-23Y-01': filtered/2019-09-15-CNI-23Y-01.IGC
# 2025-04-15 22:27:03,184 - INFO - Attempting to load IGC file for Flight '2023-08-24-CNI-25N-01': filtered/2023-08-24-CNI-25N-01.IGC
# 2025-04-15 22:27:03,185 - INFO - Distance traveled calculated: 6.369163415915397 miles
# 2025-04-15 22:27:03,189 - INFO - Descent rate calculated: -1.4933333333333334 ft/s
# 2025-04-15 22:27:03,199 - INFO - Distance traveled calculated: 8.718394154153621 miles
# 2025-04-15 22:27:03,206 - INFO - Descent rate calculated: 0.9433333333333334 ft/s
# 2025-04-15 22:27:03,207 - INFO - File '2019-09-15-CNI-23Y-01': IGC file loaded successfully.
# 2025-04-15 22:27:03,208 - INFO - Descent rate calculated: -1.0733333333333333 ft/s
# 2025-04-15 22:27:03,217 - INFO - Distance traveled calculated: 6.131712373521367 miles
# 2025-04-15 22:27:03,219 - INFO - Distance traveled calculated: 8.039378793937727 miles
# 2025-04-15 22:27:03,270 - INFO - Attempting to load IGC file for Flight '04LC4A41': filtered/04LC4A41.IGC
# 2025-04-15 22:27:03,287 - INFO - Attempting to load IGC file for Flight '2024-06-22-CNI-27D-01': filtered/2024-06-22-CNI-27D-01.IGC
# 2025-04-15 22:27:03,320 - INFO - File '2018-07-04-LXV-3IL-01': IGC file loaded successfully.
# 2025-04-15 22:27:03,321 - INFO - File '04LC4A41': IGC file loaded successfully.
# 2025-04-15 22:27:03,322 - INFO - Descent rate calculated: 0.09090909090909091 ft/s
# 2025-04-15 22:27:03,323 - INFO - Descent rate calculated: -0.3933333333333333 ft/s
# 2025-04-15 22:27:03,326 - INFO - Distance traveled calculated: 0.04822355044434877 miles
# 2025-04-15 22:27:03,326 - INFO - Attempting to load IGC file for Flight '2019-06-17-CNI-20E-01': filtered/2019-06-17-CNI-20E-01.IGC
# 2025-04-15 22:27:03,334 - INFO - Distance traveled calculated: 6.589260892678989 miles
# 2025-04-15 22:27:03,362 - INFO - File '2019-06-17-CNI-20E-01': IGC file loaded successfully.
# 2025-04-15 22:27:03,363 - INFO - Descent rate calculated: -0.6566666666666666 ft/s
# 2025-04-15 22:27:03,365 - INFO - Descent rate calculated: -1.2733333333333334 ft/s
# 2025-04-15 22:27:03,375 - INFO - Distance traveled calculated: 5.704741558165099 miles
# 2025-04-15 22:27:03,375 - INFO - Distance traveled calculated: 7.986746984521019 miles
# 2025-04-15 22:27:03,413 - INFO - File '2023-08-24-CNI-25N-01': IGC file loaded successfully.
# 2025-04-15 22:27:03,415 - INFO - Descent rate calculated: -0.047619047619047616 ft/s
# 2025-04-15 22:27:03,419 - INFO - Distance traveled calculated: 0.07544323328470066 miles
# 2025-04-15 22:27:03,425 - INFO - Attempting to load IGC file for Flight '14IGA531': filtered/14IGA531.IGC
# 2025-04-15 22:27:03,454 - INFO - Attempting to load IGC file for Flight '2022-03-13-CNI-27G-01': filtered/2022-03-13-CNI-27G-01.IGC
# 2025-04-15 22:27:03,471 - INFO - File '14IGA531': IGC file loaded successfully.
# 2025-04-15 22:27:03,473 - INFO - Descent rate calculated: 0.0 ft/s
# 2025-04-15 22:27:03,476 - INFO - Distance traveled calculated: 0.08484888605832859 miles
# 2025-04-15 22:27:03,483 - INFO - File '2022-03-13-CNI-27G-01': IGC file loaded successfully.
# 2025-04-15 22:27:03,485 - INFO - Descent rate calculated: 0.3233333333333333 ft/s
# 2025-04-15 22:27:03,495 - INFO - Distance traveled calculated: 4.666293270924707 miles
# 2025-04-15 22:27:03,503 - INFO - Attempting to load IGC file for Flight '44OLCS71': filtered/44OLCS71.IGC
# 2025-04-15 22:27:03,524 - INFO - File '2024-06-22-CNI-27D-01': IGC file loaded successfully.
# 2025-04-15 22:27:03,525 - INFO - Descent rate calculated: -2.3666666666666667 ft/s
# 2025-04-15 22:27:03,526 - INFO - Descent rate calculated: 0.48936170212765956 ft/s
# 2025-04-15 22:27:03,534 - INFO - Distance traveled calculated: 0.4652335238191578 miles
# 2025-04-15 22:27:03,535 - INFO - Distance traveled calculated: 10.829644225320108 miles
# 2025-04-15 22:27:03,537 - INFO - Attempting to load IGC file for Flight '2017-03-17-CNI-22G-01': filtered/2017-03-17-CNI-22G-01.IGC
# 2025-04-15 22:27:03,539 - INFO - File '44OLCS71': IGC file loaded successfully.
# 2025-04-15 22:27:03,540 - INFO - Descent rate calculated: -0.6133333333333333 ft/s
# 2025-04-15 22:27:03,549 - INFO - Distance traveled calculated: 4.556071858208471 miles
# 2025-04-15 22:27:03,554 - INFO - Attempting to load IGC file for Flight '2018-04-19-NKL-10Q-01': filtered/2018-04-19-NKL-10Q-01.IGC
# 2025-04-15 22:27:03,558 - INFO - Attempting to load IGC file for Flight '2023-08-17-CNI-25N-01': filtered/2023-08-17-CNI-25N-01.IGC
# 2025-04-15 22:27:03,583 - INFO - File '2017-03-17-CNI-22G-01': IGC file loaded successfully.
# 2025-04-15 22:27:03,585 - INFO - Descent rate calculated: 1.633587786259542 ft/s
# 2025-04-15 22:27:03,586 - INFO - Attempting to load IGC file for Flight '2021-07-22-LXV-780-01': filtered/2021-07-22-LXV-780-01.IGC
# 2025-04-15 22:27:03,592 - INFO - Distance traveled calculated: 1.8597046341058119 miles
# 2025-04-15 22:27:03,608 - INFO - Attempting to load IGC file for Flight '03DG8KM1': filtered/03DG8KM1.IGC
# 2025-04-15 22:27:03,629 - INFO - File '2018-04-19-NKL-10Q-01': IGC file loaded successfully.
# 2025-04-15 22:27:03,631 - INFO - Descent rate calculated: -1.59 ft/s
# 2025-04-15 22:27:03,637 - INFO - Attempting to load IGC file for Flight '2015-06-06-CNI-V8R-01': filtered/2015-06-06-CNI-V8R-01.IGC
# 2025-04-15 22:27:03,650 - INFO - Descent rate calculated: 0.57 ft/s
# 2025-04-15 22:27:03,661 - INFO - Distance traveled calculated: 4.619069059536521 miles
# 2025-04-15 22:27:03,661 - INFO - File '03DG8KM1': IGC file loaded successfully.
# 2025-04-15 22:27:03,663 - INFO - Descent rate calculated: -0.01910828025477707 ft/s
# 2025-04-15 22:27:03,666 - INFO - Distance traveled calculated: 0.09678145324749987 miles
# 2025-04-15 22:27:03,671 - INFO - Distance traveled calculated: 5.325807214350353 miles
# 2025-04-15 22:27:03,687 - INFO - Descent rate calculated: -0.05 ft/s
# 2025-04-15 22:27:03,697 - INFO - File '2015-06-06-CNI-V8R-01': IGC file loaded successfully.
# 2025-04-15 22:27:03,698 - INFO - Distance traveled calculated: 7.388574223044466 miles
# 2025-04-15 22:27:03,699 - INFO - Descent rate calculated: 0.041666666666666664 ft/s
# 2025-04-15 22:27:03,702 - INFO - Distance traveled calculated: 0.05692454106362284 miles
# 2025-04-15 22:27:03,705 - INFO - File '2021-07-22-LXV-780-01': IGC file loaded successfully.
# 2025-04-15 22:27:03,705 - INFO - Attempting to load IGC file for Flight '2016-04-19-CNI-20E-01': filtered/2016-04-19-CNI-20E-01.IGC
# 2025-04-15 22:27:03,707 - INFO - Descent rate calculated: -0.0106951871657754 ft/s
# 2025-04-15 22:27:03,728 - INFO - Distance traveled calculated: 0.1723322830009803 miles
# 2025-04-15 22:27:03,729 - INFO - File '2016-04-19-CNI-20E-01': IGC file loaded successfully.
# 2025-04-15 22:27:03,730 - INFO - Descent rate calculated: -0.8664383561643836 ft/s
# 2025-04-15 22:27:03,735 - INFO - Distance traveled calculated: 5.909569770181432 miles
# 2025-04-15 22:27:03,751 - INFO - Attempting to load IGC file for Flight '2019-07-19-CNI-27D-01': filtered/2019-07-19-CNI-27D-01.IGC
# 2025-04-15 22:27:03,792 - INFO - Attempting to load IGC file for Flight '2019-08-20-CNI-23Y-01': filtered/2019-08-20-CNI-23Y-01.IGC
# 2025-04-15 22:27:03,792 - INFO - Attempting to load IGC file for Flight '2024-06-01-CNI-242-01': filtered/2024-06-01-CNI-242-01.IGC
# 2025-04-15 22:27:03,798 - INFO - File '2023-08-17-CNI-25N-01': IGC file loaded successfully.
# 2025-04-15 22:27:03,800 - INFO - File '2019-07-19-CNI-27D-01': IGC file loaded successfully.
# 2025-04-15 22:27:03,802 - INFO - Descent rate calculated: 0.125 ft/s
# 2025-04-15 22:27:03,804 - INFO - Descent rate calculated: -0.045454545454545456 ft/s
# 2025-04-15 22:27:03,806 - INFO - Distance traveled calculated: 0.11086418935402037 miles
# 2025-04-15 22:27:03,810 - INFO - Distance traveled calculated: 0.0736932448597228 miles
# 2025-04-15 22:27:03,831 - INFO - File '2019-08-20-CNI-23Y-01': IGC file loaded successfully.
# 2025-04-15 22:27:03,833 - INFO - Descent rate calculated: 0.0 ft/s
# 2025-04-15 22:27:03,836 - INFO - Distance traveled calculated: 0.06437243545425517 miles
# 2025-04-15 22:27:03,843 - INFO - Descent rate calculated: -1.0 ft/s
# 2025-04-15 22:27:03,854 - INFO - Distance traveled calculated: 6.457463744461463 miles
# 2025-04-15 22:27:03,881 - INFO - Descent rate calculated: -0.9733333333333334 ft/s
# 2025-04-15 22:27:03,892 - INFO - Distance traveled calculated: 5.756834896715032 miles
# 2025-04-15 22:27:03,910 - INFO - Attempting to load IGC file for Flight '05JE6AB1': filtered/05JE6AB1.IGC
# 2025-04-15 22:27:03,912 - INFO - Attempting to load IGC file for Flight '2023-06-29-LXV-7EO-02': filtered/2023-06-29-LXV-7EO-02.IGC
# 2025-04-15 22:27:03,951 - INFO - File '05JE6AB1': IGC file loaded successfully.
# 2025-04-15 22:27:03,953 - INFO - Descent rate calculated: -0.5833333333333334 ft/s
# 2025-04-15 22:27:03,959 - INFO - Descent rate calculated: 0.3 ft/s
# 2025-04-15 22:27:03,963 - INFO - Distance traveled calculated: 5.424972443743961 miles
# 2025-04-15 22:27:03,970 - INFO - Distance traveled calculated: 6.994648716508773 miles
# 2025-04-15 22:27:03,990 - INFO - File '2024-06-01-CNI-242-01': IGC file loaded successfully.
# 2025-04-15 22:27:03,992 - INFO - Descent rate calculated: 0.045454545454545456 ft/s
# 2025-04-15 22:27:03,997 - INFO - Distance traveled calculated: 0.08480085142149381 miles
# 2025-04-15 22:27:04,011 - INFO - Attempting to load IGC file for Flight '2021-06-15-LXV-780-01': filtered/2021-06-15-LXV-780-01.IGC
# 2025-04-15 22:27:04,013 - INFO - Attempting to load IGC file for Flight '2012-10-13-NKL-10R-01': filtered/2012-10-13-NKL-10R-01.IGC
# 2025-04-15 22:27:04,021 - INFO - Attempting to load IGC file for Flight '35JC48C3': filtered/35JC48C3.IGC
# 2025-04-15 22:27:04,051 - INFO - File '2023-06-29-LXV-7EO-02': IGC file loaded successfully.
# 2025-04-15 22:27:04,053 - INFO - Descent rate calculated: 0.011494252873563218 ft/s
# 2025-04-15 22:27:04,067 - INFO - Attempting to load IGC file for Flight '2018-03-13-NKL-0TK-01': filtered/2018-03-13-NKL-0TK-01.IGC
# 2025-04-15 22:27:04,067 - INFO - File '2021-06-15-LXV-780-01': IGC file loaded successfully.
# 2025-04-15 22:27:04,068 - INFO - Descent rate calculated: 0.011235955056179775 ft/s
# 2025-04-15 22:27:04,072 - INFO - File '2012-10-13-NKL-10R-01': IGC file loaded successfully.
# 2025-04-15 22:27:04,074 - INFO - Distance traveled calculated: 0.1620416266375912 miles
# 2025-04-15 22:27:04,074 - INFO - Descent rate calculated: -0.6433333333333333 ft/s
# 2025-04-15 22:27:04,084 - INFO - Distance traveled calculated: 5.831530678903614 miles
# 2025-04-15 22:27:04,089 - INFO - Distance traveled calculated: 0.1739957249655295 miles
# 2025-04-15 22:27:04,091 - INFO - File '35JC48C3': IGC file loaded successfully.
# 2025-04-15 22:27:04,091 - INFO - File '2018-03-13-NKL-0TK-01': IGC file loaded successfully.
# 2025-04-15 22:27:04,092 - INFO - Descent rate calculated: -0.5544217687074829 ft/s
# 2025-04-15 22:27:04,092 - INFO - Descent rate calculated: 0.02564102564102564 ft/s
# 2025-04-15 22:27:04,096 - INFO - Distance traveled calculated: 0.10599717710896678 miles
# 2025-04-15 22:27:04,097 - INFO - Distance traveled calculated: 4.858836017442108 miles
# 2025-04-15 22:27:04,108 - INFO - Attempting to load IGC file for Flight '46AGA9D1': filtered/46AGA9D1.IGC
# 2025-04-15 22:27:04,119 - INFO - Attempting to load IGC file for Flight '2024-06-24-CNI-27D-01': filtered/2024-06-24-CNI-27D-01.IGC
# 2025-04-15 22:27:04,208 - INFO - Attempting to load IGC file for Flight '05JC3KG1': filtered/05JC3KG1.IGC
# 2025-04-15 22:27:04,212 - INFO - Descent rate calculated: -0.20666666666666667 ft/s
# 2025-04-15 22:27:04,223 - INFO - Distance traveled calculated: 5.87417203336386 miles
# 2025-04-15 22:27:04,225 - INFO - File '05JC3KG1': IGC file loaded successfully.
# 2025-04-15 22:27:04,227 - INFO - Descent rate calculated: 2.1215686274509804 ft/s
# 2025-04-15 22:27:04,227 - INFO - Attempting to load IGC file for Flight '2019-06-18-CNI-27D-01': filtered/2019-06-18-CNI-27D-01.IGC
# 2025-04-15 22:27:04,237 - INFO - Distance traveled calculated: 4.5683348967031225 miles
# 2025-04-15 22:27:04,249 - INFO - Attempting to load IGC file for Flight '2014-08-04-NKL-10X-01': filtered/2014-08-04-NKL-10X-01.IGC
# 2025-04-15 22:27:04,252 - INFO - Descent rate calculated: -0.54421768707483 ft/s
# 2025-04-15 22:27:04,253 - INFO - Attempting to load IGC file for Flight '2018-06-14-CNI-20E-01': filtered/2018-06-14-CNI-20E-01.IGC
# 2025-04-15 22:27:04,256 - INFO - Distance traveled calculated: 4.8000832615319355 miles
# 2025-04-15 22:27:04,264 - INFO - File '2024-06-24-CNI-27D-01': IGC file loaded successfully.
# 2025-04-15 22:27:04,265 - INFO - Descent rate calculated: -0.05263157894736842 ft/s
# 2025-04-15 22:27:04,267 - INFO - Attempting to load IGC file for Flight '2018-06-17-CNI-20B-01': filtered/2018-06-17-CNI-20B-01.IGC
# 2025-04-15 22:27:04,270 - INFO - Distance traveled calculated: 0.06872346064080016 miles
# 2025-04-15 22:27:04,298 - INFO - File '2018-06-17-CNI-20B-01': IGC file loaded successfully.
# 2025-04-15 22:27:04,299 - INFO - Descent rate calculated: -1.42 ft/s
# 2025-04-15 22:27:04,299 - INFO - Descent rate calculated: 0.0967741935483871 ft/s
# 2025-04-15 22:27:04,303 - INFO - Distance traveled calculated: 0.0839386175082115 miles
# 2025-04-15 22:27:04,305 - INFO - File '2018-06-14-CNI-20E-01': IGC file loaded successfully.
# 2025-04-15 22:27:04,307 - INFO - Descent rate calculated: -1.0066666666666666 ft/s
# 2025-04-15 22:27:04,310 - INFO - File '2019-06-18-CNI-27D-01': IGC file loaded successfully.
# 2025-04-15 22:27:04,311 - INFO - Descent rate calculated: 0.0 ft/s
# ...
# 2025-04-15 22:27:43,359 - WARNING - Error processing speed for row 467: [Errno 2] No such file or directory: 'TAS_wgc/2022-09-19-CNI-28S-01.IGC'
# 2025-04-15 22:27:43,360 - WARNING - Error processing speed for row 468: [Errno 2] No such file or directory: 'TAS_wgc/2017-07-02-NKL-10R-01.IGC'
# 2025-04-15 22:27:43,360 - WARNING - Error processing speed for row 471: [Errno 2] No such file or directory: 'TAS_wgc/2017-03-10-LXV-1OL-01.IGC'
# 2025-04-15 22:27:43,361 - WARNING - Error processing speed for row 473: [Errno 2] No such file or directory: 'TAS_wgc/2016-06-11-CNI-20E-01.IGC'
# 2025-04-15 22:27:43,361 - WARNING - Error processing speed for row 474: [Errno 2] No such file or directory: 'TAS_wgc/2024-06-10-CNI-24W-01.IGC'
# 2025-04-15 22:27:43,362 - WARNING - Error processing speed for row 477: [Errno 2] No such file or directory: 'TAS_wgc/2013-04-26-NKL-10Q-01.IGC'
# 2025-04-15 22:27:43,362 - WARNING - Error processing speed for row 480: [Errno 2] No such file or directory: 'TAS_wgc/2015-05-16-NKL-10R-01.IGC'
# 2025-04-15 22:27:43,363 - WARNING - Error processing speed for row 484: [Errno 2] No such file or directory: 'TAS_wgc/2019-04-22-CNI-22A-01.IGC'
# 2025-04-15 22:27:43,364 - WARNING - Error processing speed for row 486: [Errno 2] No such file or directory: 'TAS_wgc/2017-08-03-CNI-255-01.IGC'
# 2025-04-15 22:27:43,365 - WARNING - Error processing speed for row 489: [Errno 2] No such file or directory: 'TAS_wgc/2016-03-12-CNI-22G-01.IGC'
# 2025-04-15 22:27:43,365 - WARNING - Error processing speed for row 490: [Errno 2] No such file or directory: 'TAS_wgc/2022-09-19-CNI-20Y-01.IGC'
# 2025-04-15 22:27:43,366 - WARNING - Error processing speed for row 491: [Errno 2] No such file or directory: 'TAS_wgc/2017-08-10-CNI-20E-01.IGC'
# 2025-04-15 22:27:43,366 - WARNING - Error processing speed for row 493: [Errno 2] No such file or directory: 'TAS_wgc/2010-08-10-NKL-0W2-01.IGC'
# 2025-04-15 22:27:43,367 - WARNING - Error processing speed for row 494: [Errno 2] No such file or directory: 'TAS_wgc/2021-06-16-CNI-28F-01.IGC'
# 2025-04-15 22:27:43,396 - WARNING - Error processing speed for row 499: [Errno 2] No such file or directory: 'TAS_wgc/05LC3KG1.IGC'
# 2025-04-15 22:27:43,397 - WARNING - Error processing speed for row 501: [Errno 2] No such file or directory: 'TAS_wgc/2015-09-24-CNI-20E-01.IGC'
# 2025-04-15 22:27:43,397 - WARNING - Error processing speed for row 502: [Errno 2] No such file or directory: 'TAS_wgc/2016-04-19-CNI-20Y-01.IGC'
# 2025-04-15 22:27:43,397 - WARNING - Error processing speed for row 503: [Errno 2] No such file or directory: 'TAS_wgc/2017-09-17-CNI-20E-01.IGC'
# 2025-04-15 22:27:43,398 - WARNING - Error processing speed for row 508: [Errno 2] No such file or directory: 'TAS_wgc/2015-05-20-CNI-20Y-01.IGC'
# 2025-04-15 22:27:43,399 - WARNING - Error processing speed for row 510: [Errno 2] No such file or directory: 'TAS_wgc/2014-05-17-NKL-13E-01.IGC'
# 2025-04-15 22:27:43,399 - WARNING - Error processing speed for row 511: [Errno 2] No such file or directory: 'TAS_wgc/2022-09-19-CNI-295-01.IGC'
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 44
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# 2025-04-15 22:27:43,400 - WARNING - Error processing speed for row 512: [Errno 2] No such file or directory: 'TAS_wgc/2015-10-14-CNI-214-01.IGC'
# 2025-04-15 22:27:43,400 - WARNING - Error processing speed for row 513: [Errno 2] No such file or directory: 'TAS_wgc/2023-06-02-CNI-29F-01.IGC'
# 2025-04-15 22:27:43,401 - WARNING - Error processing speed for row 514: [Errno 2] No such file or directory: 'TAS_wgc/04MC4A41.IGC'
# 2025-04-15 22:27:43,402 - WARNING - Error processing speed for row 520: [Errno 2] No such file or directory: 'TAS_wgc/2019-04-24-CNI-28S-01.IGC'
# 2025-04-15 22:27:43,402 - WARNING - Error processing speed for row 521: [Errno 2] No such file or directory: 'TAS_wgc/2018-07-03-LXV-3IL-01.IGC'
# 2025-04-15 22:27:43,402 - WARNING - Error processing speed for row 522: [Errno 2] No such file or directory: 'TAS_wgc/2018-06-28-CNI-27G-01.IGC'
# 2025-04-15 22:27:43,403 - WARNING - Error processing speed for row 524: [Errno 2] No such file or directory: 'TAS_wgc/2016-05-23-NKL-10R-01.IGC'
# 2025-04-15 22:27:43,404 - WARNING - Error processing speed for row 527: [Errno 2] No such file or directory: 'TAS_wgc/2019-10-09-CNI-20E-01.IGC'
# 2025-04-15 22:27:43,405 - WARNING - Error processing speed for row 530: [Errno 2] No such file or directory: 'TAS_wgc/65BV1WZ1.IGC'
# 2025-04-15 22:27:43,406 - WARNING - Error processing speed for row 532: [Errno 2] No such file or directory: 'TAS_wgc/2022-10-06-CNI-29F-01.IGC'
# 2025-04-15 22:27:43,406 - WARNING - Error processing speed for row 533: [Errno 2] No such file or directory: 'TAS_wgc/2018-04-19-CNI-20E-01.IGC'
# 2025-04-15 22:27:43,407 - WARNING - Error processing speed for row 535: [Errno 2] No such file or directory: 'TAS_wgc/2016-05-09-CNI-20E-01.IGC'
# 2025-04-15 22:27:43,407 - WARNING - Error processing speed for row 537: [Errno 2] No such file or directory: 'TAS_wgc/2021-08-07-CNI-23Y-01.IGC'
# 2025-04-15 22:27:43,443 - WARNING - Error processing speed for row 541: [Errno 2] No such file or directory: 'TAS_wgc/2017-08-05-CNI-20E-01.IGC'
# 2025-04-15 22:27:43,444 - WARNING - Error processing speed for row 542: [Errno 2] No such file or directory: 'TAS_wgc/2021-06-05-CNI-20E-01.IGC'
# 2025-04-15 22:27:43,444 - WARNING - Error processing speed for row 543: [Errno 2] No such file or directory: 'TAS_wgc/2013-07-29-NKL-12K-01.IGC'
# 2025-04-15 22:27:43,445 - WARNING - Error processing speed for row 545: [Errno 2] No such file or directory: 'TAS_wgc/2024-06-18-FLA-1D0-01.IGC'
# 2025-04-15 22:27:43,445 - WARNING - Error processing speed for row 547: [Errno 2] No such file or directory: 'TAS_wgc/2013-03-15-NKL-10Q-01.IGC'
# 2025-04-15 22:27:43,446 - WARNING - Error processing speed for row 548: [Errno 2] No such file or directory: 'TAS_wgc/2015-06-15-CNI-205-01.IGC'
# 2025-04-15 22:27:43,482 - WARNING - Error processing speed for row 551: [Errno 2] No such file or directory: 'TAS_wgc/938V1KO1.igc'
# 2025-04-15 22:27:43,512 - WARNING - Error processing speed for row 559: [Errno 2] No such file or directory: 'TAS_wgc/13CC4A41.igc'
# 2025-04-15 22:27:43,513 - WARNING - Error processing speed for row 560: [Errno 2] No such file or directory: 'TAS_wgc/13EC4A41.igc'
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# 2025-04-15 22:27:43,719 - WARNING - Error processing speed for row 577: [Errno 2] No such file or directory: 'TAS_wgc/45VV40R1.igc'
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# 2025-04-15 22:27:43,930 - WARNING - Error processing speed for row 589: [Errno 2] No such file or directory: 'TAS_wgc/54LV1OL1.igc'
# 2025-04-15 22:27:43,967 - WARNING - Error processing speed for row 608: [Errno 2] No such file or directory: 'TAS_wgc/2024-06-01-LXV-4RD-01.igc'
# 2025-04-15 22:27:44,010 - WARNING - Error processing speed for row 617: [Errno 2] No such file or directory: 'TAS_wgc/2021-07-04-LXV-59J-01.igc'
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 44, end = 48
# DEBUG: Found TAS positions: start = 42, end = 46
# 2025-04-15 22:27:44,103 - WARNING - Error processing speed for row 635: [Errno 2] No such file or directory: 'TAS_wgc/13HC4A41.igc'
# 2025-04-15 22:27:44,105 - WARNING - Error processing speed for row 640: [Errno 2] No such file or directory: 'TAS_wgc/2024-03-20-NAV-170863-01.igc'
# 2025-04-15 22:27:44,106 - WARNING - Error processing speed for row 644: [Errno 2] No such file or directory: 'TAS_wgc/04JC4A41.igc'
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# 2025-04-15 22:27:44,584 - WARNING - Error processing speed for row 704: [Errno 2] No such file or directory: 'TAS_wgc/13FC4A41.igc'
# 2025-04-15 22:27:44,626 - WARNING - Error processing speed for row 707: [Errno 2] No such file or directory: 'TAS_wgc/2021-06-28-LXV-59J-01.igc'
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# 2025-04-15 22:27:44,712 - WARNING - Error processing speed for row 719: [Errno 2] No such file or directory: 'TAS_wgc/99FV1KO1.igc'
# 2025-04-15 22:27:44,785 - WARNING - Error processing speed for row 724: [Errno 2] No such file or directory: 'TAS_wgc/456VJBN1.igc'
# 2025-04-15 22:27:44,822 - WARNING - Error processing speed for row 739: [Errno 2] No such file or directory: 'TAS_wgc/2023-08-14-NAV-6OD-01.igc'
# 2025-04-15 22:27:44,912 - WARNING - Error processing speed for row 748: [Errno 2] No such file or directory: 'TAS_wgc/174c48r6.igc'
# 2025-04-15 22:27:44,914 - WARNING - Error processing speed for row 752: [Errno 2] No such file or directory: 'TAS_wgc/14IV1WZ7.igc'
# 2025-04-15 22:27:44,915 - WARNING - Error processing speed for row 753: [Errno 2] No such file or directory: 'TAS_wgc/26oc4ky1.igc'
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# 2025-04-15 22:27:44,953 - WARNING - Error processing speed for row 765: [Errno 2] No such file or directory: 'TAS_wgc/04KC4A41.igc'
# 2025-04-15 22:27:44,953 - WARNING - Error processing speed for row 767: [Errno 2] No such file or directory: 'TAS_wgc/2022-03-17-NAV-8RQ-01.igc'
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# 2025-04-15 22:27:45,288 - WARNING - Error processing speed for row 804: [Errno 2] No such file or directory: 'TAS_wgc/13DC4A41.igc'
# 2025-04-15 22:27:45,290 - WARNING - Error processing speed for row 809: [Errno 2] No such file or directory: 'TAS_wgc/13IC4A41.igc'
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# 2025-04-15 22:27:45,492 - WARNING - Error processing speed for row 821: [Errno 2] No such file or directory: 'TAS_wgc/2024-06-07-NAV-180804-01.igc'
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# 2025-04-15 22:27:45,665 - WARNING - Error processing speed for row 835: [Errno 2] No such file or directory: 'TAS_wgc/2024-03-19-NAV-170863-01.igc'
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 44, end = 48
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# 2025-04-15 22:27:45,817 - WARNING - Error processing speed for row 852: [Errno 2] No such file or directory: 'TAS_wgc/13JC4A41.igc'
# 2025-04-15 22:27:45,866 - WARNING - Error processing speed for row 858: [Errno 2] No such file or directory: 'TAS_wgc/54NV1OL1.igc'
# 2025-04-15 22:27:45,949 - WARNING - Error processing speed for row 870: [Errno 2] No such file or directory: 'TAS_wgc/18D_JP.igc'
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 44, end = 48
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 44, end = 48
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 44, end = 48
# DEBUG: Found TAS positions: start = 44, end = 48
# DEBUG: Found TAS positions: start = 44, end = 48
# DEBUG: Found TAS positions: start = 44, end = 48
# DEBUG: Found TAS positions: start = 44, end = 48
# DEBUG: Found TAS positions: start = 44, end = 48
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 44, end = 48
# DEBUG: Found TAS positions: start = 44, end = 48
# DEBUG: Found TAS positions: start = 44, end = 48
# DEBUG: Found TAS positions: start = 44, end = 48
# DEBUG: Found TAS positions: start = 44, end = 48
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 44, end = 48
# DEBUG: Found TAS positions: start = 44, end = 48
# DEBUG: Found TAS positions: start = 44, end = 48
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 44, end = 48
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 44, end = 48
# DEBUG: Found TAS positions: start = 44, end = 48
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 44, end = 48
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 42, end = 46
# 2025-04-15 22:27:48,222 - WARNING - Error processing speed for row 1077: [Errno 2] No such file or directory: 'TAS_wgc/4536-9239003653.igc'
# 2025-04-15 22:27:48,282 - INFO - ✅ Stage 2 complete: Final CSV with speed columns saved as flights_final.csv
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 44, end = 48
# DEBUG: Found TAS positions: start = 42, end = 46
# DEBUG: Found TAS positions: start = 44, end = 48

# %%
df=df[df['min_speed_while_engine_running (knots)']!="0.00"]

# %%
df['Engine_Start_Above_1000ft'].value_counts()
# Out:
# Engine_Start_Above_1000ft
# False                                                                                              105
# True                                                                                                94
# False,True                                                                                          60
# False,False                                                                                         46
# True,True                                                                                           17
# True,False                                                                                           9
# False,False,True                                                                                     8
# False,True,True                                                                                      7
# False,False,False                                                                                    6
# True,True,True                                                                                       5
# True,True,True,False                                                                                 3
# True,True,True,True,True,True,True,True,True                                                         2
# False,True,True,True                                                                                 2
# False,False,True,True,True,True                                                                      2
# True,True,True,True,True,True,True,True,True,True,True,True,True                                     2
# True,True,True,True,True,True,True,True,True,True,True,True,True,False                               2
# True,True,True,True,False                                                                            2
# False,True,False                                                                                     2
# True,True,True,True,True,True,True,False                                                             1
# True,False,False,False,False                                                                         1
# True,True,True,True,True                                                                             1
# False,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True      1
# True,False,False                                                                                     1
# False,False,True,False,True                                                                          1
# True,True,False                                                                                      1
# True,True,True,True,True,True,True,True,False                                                        1
# False,True,True,False                                                                                1
# False,False,False,False                                                                              1
# False,True,True,True,True                                                                            1
# False,False,False,True,True                                                                          1
# True,True,True,True,True,True,True,True,False,True                                                   1
# True,True,True,True,False,True,True,True,False                                                       1
# False,False,True,False,False                                                                         1
# True,True,True,True,True,True,True,True,True,True,True,True,True,True,True                           1
# True,True,True,True,True,True,True,True,True,True                                                    1
# False,True,False,True,False                                                                          1
# False,False,True,False                                                                               1
# True,True,True,True,True,True,True,True,True,True,True,False                                         1
# True,True,True,True,True,True,True,True,True,True,True                                               1
# True,True,True,True,True,False                                                                       1
# False,False,False,False,True                                                                         1
# True,True,True,True,True,True,True,True,True,True,True,True,False                                    1
# True,True,True,True,True,True,True,True,False,True,True,True,True                                    1
# False,False,False,True,True,False                                                                    1
# False,True,True,True,True,True                                                                       1
# Name: count, dtype: int64

# %%
df.columns

# %%
Gtypes= set(df['Gtype'])

# %%
# Convert the set to a list and then to a DataFrame
df_gtypes = pd.DataFrame(list(Gtypes), columns=['Gtype'])

# Write the DataFrame to a CSV file (without the index)
#df_gtypes.to_csv('Gtypes.csv', index=False)

# %%
# If the column is numeric, just assign it.
df['avg_speed_while_engine_running (knots)'] = pd.to_numeric(
    df['avg_speed_while_engine_running (knots)'],
    errors='coerce'
)
